# %% [markdown]
# # Problem Set 2: Intro to Pandas

# %% [markdown]
# ## Part 1
#
# In this problem set, we want to determine if we can use voter registrations as a proxy for votes cast. Because who you vote for on an individual basis is not recorded, we would like to see if the numbers for those registered in a precinct as Republican or Democrate actually reflect the results of the election based on the outcome. We'll continue our analysis of Centre County, Pennsylvania, and we are going to use Pandas, Numpy, and Matplotlib as our tools to explore the data.
#
#
# Building off the in class example, first a short example will introduce us to the dataset, some data wrangling functions of Pandas, and a few plots with Matplotlib.
#
#
#
# Throughout the exercises we will be continuously using Pandas and some of its merging functionality to join the numerous OD files available. We will be building exploratory data visualizations, finding urban patterns and locating divergent areas within the dataset. Some useful documentation for merging data with Pandas can be found at:
#
#
# http://pandas.pydata.org/pandas-docs/stable/merging.html

# %% [markdown]
# First, lets install our libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from itertools import cycle, islice

# This line lets us plot on our ipython notebook
# %matplotlib inline

# %% [markdown]
# Next, let's open up one of the files. Let's look at the voter registrations, this is the same as we did in the inclass.
#
# **Problem 1: Load CENTER_FVE_20170123.csv into Pandas as a data frame called 'df_voters'.**

# %%
# We are reading a CSV with election data
df_voters = pd.read_table('data/CENTRE_FVE_20170123.csv', sep=',', low_memory=False)
df_voters
# Out:
#                    1    2            3            4       5    6    7  \
# 0       002013865-14  NaN        MILLS        JAMES  ARTHUR  NaN    M
# 1       002020582-14  NaN        TERRY      CHARLES       D  NaN    U
# 2       002287451-14  NaN      MURRELL      RICHARD       L  NaN    M
# 3       002365541-14  NaN        MILLS        JOYCE   ELLEN  NaN    F
# 4       002370224-14  NaN       FENTON        CASEY   JAMES  NaN    M
# 5       002572852-14  NaN      MURRELL        SUSAN       L  NaN    F
# 6       004529096-14  NaN         HAIR       STEVEN       M  NaN    M
# 7       005138406-14  NaN       BROOKS        HARRY       C  NaN    M
# 8       005163451-14  NaN       BROOKS        DEBRA  LOUISE  NaN    F
# 9       005194526-14  NaN    GENSIMORE         GARY   DAVID  NaN    M
# 10      005881492-14  NaN       GRAHAM      KATHRYN     LEE  NaN    F
# 11      007026230-14  NaN    SCHNEIDER       WALTER       G  NaN    M
# 12      007094976-14  NaN       MURRAY      RACHAEL       R  NaN    U
# 13      007376473-14  NaN        OCKER      ROSALIE    JEAN  NaN    F
# 14      007398108-14  NaN        OCKER         JEAN       E  NaN    F
# 15      009621382-14  NaN     MACHIKAS    ALEXANDRA       M  NaN    F
# 16      009878128-14  NaN     BRUNGARD         LARA       C  NaN    F
# 17      010437417-14  NaN       RANKIN        LUCAS  ROBERT  NaN    M
# 18      010464969-14  NaN        SHENK        COLBY    RYAN  NaN    M
# 19      010573042-14  NaN     STEPHENS         ERIN       L  NaN    F
# 20      010634062-14  NaN       STEVER       SHEILA       M  NaN    F
# 21      010849083-14  NaN        SMITH      ANNETTE       L  NaN    F
# 22      010849366-14  NaN        MENNA     FRANKLIN       M  NaN    U
# 23      010855262-14  NaN       PROVAN        DAVID       A  NaN    U
# 24      010857411-14  NaN       WALKER        RALPH       E  NaN    U
# 25      010858336-14  NaN      NASTASE    ELIZABETH       E  NaN    U
A ...  NaN   AP    R  NaN  NaN  NaN  NaN
# 7        3/19/50    1/1/01  A ...    R   AP    R  NaN  NaN   AP    R
# 8        5/22/51   3/15/91  A ...    R   AP    R  NaN  NaN   AP    R
# 9         3/6/68   5/22/96  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10       2/12/47   8/29/96  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11       5/29/71   1/31/92  A ...    R   AP    R   AP    R  NaN  NaN
# 12       6/19/76   5/16/00  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13       3/10/58    7/5/02  A ...  NaN   AP    D  NaN  NaN   AP    D
# 14       4/16/29    9/4/62  A ...  NaN   AP    D  NaN  NaN  NaN  NaN
# 15        3/2/87   6/16/05  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16        3/2/83   3/18/04  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17       1/31/80   4/21/98  A ...    R   AP    R   AP    R   AP    R
# 18       9/29/73    9/4/97  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19      12/13/74    7/3/02  A ...  NaN   AP    D   AP    D   AP    D
# 20       11/1/66   10/9/84  A ...  NaN   AP   NF  NaN  NaN  NaN  NaN
# 21        3/2/45   8/28/68  A ...    D   AP    D   AP    D   AP    D
# 22       1/13/50   8/28/76  A ...  NaN   AP    D  NaN  NaN   AP    D
# 23       1/16/52   3/29/76  A ...    D   AP    D   AP    D   AP    D
# 24       3/15/41   2/27/64  A ...    R   AP    R   AP    R   AP    R
# 25      11/18/25   2/13/47  A ...    D   AP    D  NaN  NaN  NaN  NaN
# 26        8/2/19   9/29/47  A ...  NaN   AB    R  NaN  NaN  NaN  NaN
# 27       4/19/27   9/11/48  A ...    R   AP    R   AP    R   AP    R
# 28        9/8/27   9/11/52  I ...  NaN  NaN  NaN  NaN  NaN   AP    R
# 29       6/10/28   9/12/52  A ...    D   AP    D  NaN  NaN   AP    D
# ...          ...       ... .. ...  ...  ...  ...  ...  ...  ...  ...
# 123413   2/22/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123414  11/10/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123415    9/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123416   12/4/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123417    4/2/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123418   5/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123419  12/29/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123420  10/10/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123421    4/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123422    4/3/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123423   2/11/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123424    8/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123425  10/26/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123426   1/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123427   4/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123428   9/18/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123429   9/19/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123430   1/22/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123431   7/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123432   9/30/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123433   2/19/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123434   9/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123435  12/31/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123436  11/21/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123437   4/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123438    4/1/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123439  10/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123440  11/24/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123441    7/1/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123442   4/16/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                151     152 153
# 0              NaN  CENTRE NaN
# 1              NaN  CENTRE NaN
# 2              NaN  CENTRE NaN
# 3              NaN  CENTRE NaN
# 4       5707687675  CENTRE NaN
# 5              NaN  CENTRE NaN
# 6              NaN  CENTRE NaN
# 7              NaN  CENTRE NaN
# 8              NaN  CENTRE NaN
# 9              NaN  CENTRE NaN
# 10      8145065538  CENTRE NaN
# 11             NaN  CENTRE NaN
# 12      6105098485  CENTRE NaN
# 13      8147691906  CENTRE NaN
# 14             NaN  CENTRE NaN
# 15             NaN  CENTRE NaN
# 16             NaN  CENTRE NaN
# 17      8143550831  CENTRE NaN
# 18             NaN  CENTRE NaN
# 19             NaN  CENTRE NaN
# 20      6108446630  CENTRE NaN
# 21         3530656  CENTRE NaN
# 22         3559388  CENTRE NaN
# 23         3559067  CENTRE NaN
# 24             NaN  CENTRE NaN
# 25         3553298  CENTRE NaN
# 26             NaN  CENTRE NaN
# 27             NaN  CENTRE NaN
# 28         3553569  CENTRE NaN
# 29             NaN  CENTRE NaN
# ...            ...     ...  ..
# 123413         NaN  CENTRE NaN
# 123414         NaN  CENTRE NaN
# 123415         NaN  CENTRE NaN
# 123416         NaN  CENTRE NaN
# 123417         NaN  CENTRE NaN
# 123418         NaN  CENTRE NaN
# 123419  5709005611  CENTRE NaN
# 123420         NaN  CENTRE NaN
# 123421         NaN  CENTRE NaN
# 123422  2036045055  CENTRE NaN
# 123423  2034614023  CENTRE NaN
# 123424         NaN  CENTRE NaN
# 123425  5709034112  CENTRE NaN
# 123426         NaN  CENTRE NaN
# 123427  5704179068  CENTRE NaN
# 123428  5709055297  CENTRE NaN
# 123429  9546629236  CENTRE NaN
# 123430  6306312989  CENTRE NaN
# 123431  5704368864  CENTRE NaN
# 123432         NaN  CENTRE NaN
# 123433         NaN  CENTRE NaN
# 123434  9732242161  CENTRE NaN
# 123435  7247775506  CENTRE NaN
# 123436  6309359977  CENTRE NaN
# 123437         NaN  CENTRE NaN
# 123438         NaN  CENTRE NaN
# 123439  6315594571  CENTRE NaN
# 123440         NaN  CENTRE NaN
# 123441         NaN  CENTRE NaN
# 123442         NaN  CENTRE NaN
#
# [123443 rows x 153 columns]

# %% [markdown]
# To start us off, we need to determine party affiliations for each of those registered. Reading in the metadata, this is held in column 12. Let's take a look at unique party registrations in column 12.
#
# **The data documentation file is located in your data folder. It will describe the fields.**

# %%
# View the unique values in column 12
df_voters['12'].unique()
# Out:
# array(['R', 'D', 'NF', 'LN', 'I', 'NON', 'AT', 'GR', 'NO', 'OTH', 'S',
#        'TP', 'AE', 'NOP', 'NST', 'SEC', 'UPP', 'GW', 'INDE', 'C', 'CT',
#        'DNV', 'AI', 'PR', 'INDd', 'IND', 'ID', 'WH', 'GP', 'PL', 'MW',
#        'AM', 'UNA', nan, 'LI', 'IAPP', 'THPY', 'IR', 'UNK', 'NTS', 'DS',
#        'SAME', 'IT', 'ICO', 'BM', 'M', 'NS', 'JD', 'LT', 'BH', 'AH', 'MZ',
#        'PG', 'PP', 'NL', 'UND', 'N', 'FD', 'IDK', 'RF', 'AYE', 'AD',
#        'PPOA', 'MA', 'MM', 'OLAP', 'CNT', 'AF', 'CON', 'GT', 'FR', 'AC',
#        'DTP', 'CH', 'SOD', 'IK', 'PZ', 'PIR', 'H', 'FE', 'COL', 'BP', 'CB',
#        'AL', 'CM', 'OP', 'IA', 'L', 'TPP', 'ACO', 'COI', 'MAJA', 'KEG'], dtype=object)

# %% [markdown]
# There are quite a few, and its pretty messy. Let's to explore MatPlotLib, let's make some charts to see which parties have the highest subscriptions and graph it in a bar chart.
#
# **Group our data so we can plot. Find the number of subscribers to each party and sum them in a table. Call your new data frame 'df_summed', name the columns 'PARTY' and 'NUMBER'**

# %%
# group data by party subscriber and sum in a table
grouped = df_voters.groupby('12') # Group by party registrations
summed = grouped['12'].count() # Get counts of each group
summed.sort_values(inplace=True, ascending=False)
df_summed = summed.to_frame()
df_summed.columns = ['NUMBER']
df_summed.index.names = ['PARTY']
df_summed
# Out:
#        NUMBER
# PARTY
# D       51162
# R       47668
# NF      17608
# NON      2814
# I        2006
# LN        805
# OTH       368
# GR        264
# INDE      183
# NO        175
# NOP       137
# IND        31
# C          24
# CT         20
# S          11
# LI         10
# IR         10
# ID          9
# UNK         7
# NTS         6
# RF          5
# UND         5
# M           5
# UNA         5
# AD          4
# GP          4
# AM          4
# WH          4
# NS          3
# MW          3
# ...       ...
# AH          1
# AF          1
# TPP         1
# ACO         1
# OLAP        1
# FE          1
# DTP         1
# MM          1
# MAJA        1
# MA          1
# OP          1
# LT          1
# PG          1
# PIR         1
# L           1
# KEG         1
# N           1
# UPP         1
# PL          1
# IK          1
# PPOA        1
# ICO         1
# IA          1
# H           1
# GW          1
# GT          1
# NST         1
# SAME        1
# FR          1
# PZ          1
#
# [92 rows x 1 columns]

# %% [markdown]
# Now, let's make a bar chart to do some initial exploration of the data. To get a simple exploratory plot, we use Matplotlib. Matplotlib is integrated into Pandas, and you can create plots from data frames. For more reading, check out the Matplotlib documentation at [Pandas Plotting Documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) and the [Matplotlib Documentation](http://matplotlib.org/2.0.0/contents.html).
#
# Using **df_summed** that you just created, the following will give you a basic bar chart of your dataset.

# %%
df_summed.plot.bar(legend=True)

# %% [markdown]
# This is alot of values! It doesn't make much sense to show them all, let's group categories into three, Republican, Democrat, or Other. We can do this doing some grouping and by implementing what we've learned so far. The following shows you how to find all of the party affiliations that are not 'Democrat' or 'Republican'.

# %%
# group into three categories: republican, democrat and other
df_summed[(df_summed.index != 'D') & (df_summed.index != 'R')]
# Out:
#        NUMBER
# PARTY
# NF      17608
# NON      2814
# I        2006
# LN        805
# OTH       368
# GR        264
# INDE      183
# NO        175
# NOP       137
# IND        31
# C          24
# CT         20
# S          11
# LI         10
# IR         10
# ID          9
# UNK         7
# NTS         6
# RF          5
# UND         5
# M           5
# UNA         5
# AD          4
# GP          4
# AM          4
# WH          4
# NS          3
# MW          3
# TP          3
# BM          3
# ...       ...
# AH          1
# AF          1
# TPP         1
# ACO         1
# OLAP        1
# FE          1
# DTP         1
# MM          1
# MAJA        1
# MA          1
# OP          1
# LT          1
# PG          1
# PIR         1
# L           1
# KEG         1
# N           1
# UPP         1
# PL          1
# IK          1
# PPOA        1
# ICO         1
# IA          1
# H           1
# GW          1
# GT          1
# NST         1
# SAME        1
# FR          1
# PZ          1
#
# [90 rows x 1 columns]

# %% [markdown]
# Group the parties into Democrat, Republican, and Other. Create a single row table with parties as the rows, and the number of voter registrations as columns. The rows should be Democrat, Republican, and Other. Call the table 'df_parties'
#
# Hint, sum the values you want from **df_summed** for each group and save them as variables. You will then need to create a new numpy array that contains the summed valued for each group and create the new data frame with your answer. This [Stack Exchange Question](http://stackoverflow.com/questions/17839973/construct-pandas-dataframe-from-values-in-variables) will help you, along with the [Pandas documentation on DataFrames](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe).

# %%
parties = ['Democrat', 'Republican', 'Other']
values = np.array([df_summed[(df_summed.index == 'D')].NUMBER.item(),df_summed[(df_summed.index == 'R')].NUMBER.item(),df_summed[(df_summed.index != 'D') & (df_summed.index != 'R')].NUMBER.sum()])
df_parties = pd.DataFrame(values,index=parties,columns=list('N'))
df_parties
# Out:
#                 N
# Democrat    51162
# Republican  47668
# Other       24609

# %% [markdown]
# **Problem 2: Plot this as a bar chart, using red for Republican, blue for Democrat, and yellow for other.**
#
# You can learn more about bar plots in in the [Bar Plot Documentation](http://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html#visualization-barplot). This will also give you hints as to how you can assign colors, along with the other properties affiated with bar charts, such as legends and axes.

# %%
# plot the bar chart by party with a specific color for each party
df_parties.plot.bar(color=['#83b2d0', '#f25050', '#fef56f'], legend=None);
plt.axhline(0, color='k')
plt.suptitle('voter registration by party in centre county, pennsylvania 2017', fontsize=20)
plt.xlabel('political party', fontsize=18)
plt.ylabel('registered voters', fontsize=16)

# %% [markdown]
# **Problem 3: For this next question, implement the above. We want to compare how the number of voter registrations to election results for one precinct (PRECINCT 42). Create a bar chart that has two bars each for category (Democrat, Republican, and Other). One of the bars will represent the number of registered voters to that party, and the second bar representing the count of results (ie how many people actually voted for that parties candidate) for each group**
#
# Hint, you will have to load the precinct level result data into Pandas, then perform the correct grouping and summing to get the numbers you need from both the voter registration data and the precinct level results, then join the two into single dataframe to make your chart. You can base your answers on the following help page: http://chrisalbon.com/python/matplotlib_grouped_bar_plot.html

# %%
# read in a CSV with election data
df_voters = pd.read_table('data/CENTRE_FVE_20170123.csv', sep=',', low_memory=False)
df_voters
# Out:
#                    1    2            3            4       5    6    7  \
# 0       002013865-14  NaN        MILLS        JAMES  ARTHUR  NaN    M
# 1       002020582-14  NaN        TERRY      CHARLES       D  NaN    U
# 2       002287451-14  NaN      MURRELL      RICHARD       L  NaN    M
# 3       002365541-14  NaN        MILLS        JOYCE   ELLEN  NaN    F
# 4       002370224-14  NaN       FENTON        CASEY   JAMES  NaN    M
# 5       002572852-14  NaN      MURRELL        SUSAN       L  NaN    F
# 6       004529096-14  NaN         HAIR       STEVEN       M  NaN    M
# 7       005138406-14  NaN       BROOKS        HARRY       C  NaN    M
# 8       005163451-14  NaN       BROOKS        DEBRA  LOUISE  NaN    F
# 9       005194526-14  NaN    GENSIMORE         GARY   DAVID  NaN    M
# 10      005881492-14  NaN       GRAHAM      KATHRYN     LEE  NaN    F
# 11      007026230-14  NaN    SCHNEIDER       WALTER       G  NaN    M
# 12      007094976-14  NaN       MURRAY      RACHAEL       R  NaN    U
# 13      007376473-14  NaN        OCKER      ROSALIE    JEAN  NaN    F
# 14      007398108-14  NaN        OCKER         JEAN       E  NaN    F
# 15      009621382-14  NaN     MACHIKAS    ALEXANDRA       M  NaN    F
# 16      009878128-14  NaN     BRUNGARD         LARA       C  NaN    F
# 17      010437417-14  NaN       RANKIN        LUCAS  ROBERT  NaN    M
# 18      010464969-14  NaN        SHENK        COLBY    RYAN  NaN    M
# 19      010573042-14  NaN     STEPHENS         ERIN       L  NaN    F
# 20      010634062-14  NaN       STEVER       SHEILA       M  NaN    F
# 21      010849083-14  NaN        SMITH      ANNETTE       L  NaN    F
# 22      010849366-14  NaN        MENNA     FRANKLIN       M  NaN    U
# 23      010855262-14  NaN       PROVAN        DAVID       A  NaN    U
# 24      010857411-14  NaN       WALKER        RALPH       E  NaN    U
A ...  NaN   AP    R  NaN  NaN  NaN  NaN
# 7        3/19/50    1/1/01  A ...    R   AP    R  NaN  NaN   AP    R
# 8        5/22/51   3/15/91  A ...    R   AP    R  NaN  NaN   AP    R
# 9         3/6/68   5/22/96  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10       2/12/47   8/29/96  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11       5/29/71   1/31/92  A ...    R   AP    R   AP    R  NaN  NaN
# 12       6/19/76   5/16/00  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13       3/10/58    7/5/02  A ...  NaN   AP    D  NaN  NaN   AP    D
# 14       4/16/29    9/4/62  A ...  NaN   AP    D  NaN  NaN  NaN  NaN
# 15        3/2/87   6/16/05  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16        3/2/83   3/18/04  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17       1/31/80   4/21/98  A ...    R   AP    R   AP    R   AP    R
# 18       9/29/73    9/4/97  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19      12/13/74    7/3/02  A ...  NaN   AP    D   AP    D   AP    D
# 20       11/1/66   10/9/84  A ...  NaN   AP   NF  NaN  NaN  NaN  NaN
# 21        3/2/45   8/28/68  A ...    D   AP    D   AP    D   AP    D
# 22       1/13/50   8/28/76  A ...  NaN   AP    D  NaN  NaN   AP    D
# 23       1/16/52   3/29/76  A ...    D   AP    D   AP    D   AP    D
# 24       3/15/41   2/27/64  A ...    R   AP    R   AP    R   AP    R
# 25      11/18/25   2/13/47  A ...    D   AP    D  NaN  NaN  NaN  NaN
# 26        8/2/19   9/29/47  A ...  NaN   AB    R  NaN  NaN  NaN  NaN
# 27       4/19/27   9/11/48  A ...    R   AP    R   AP    R   AP    R
# 28        9/8/27   9/11/52  I ...  NaN  NaN  NaN  NaN  NaN   AP    R
# 29       6/10/28   9/12/52  A ...    D   AP    D  NaN  NaN   AP    D
# ...          ...       ... .. ...  ...  ...  ...  ...  ...  ...  ...
# 123413   2/22/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123414  11/10/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123415    9/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123416   12/4/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123417    4/2/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123418   5/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123419  12/29/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123420  10/10/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123421    4/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123422    4/3/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123423   2/11/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123424    8/5/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123425  10/26/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123426   1/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123427   4/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123428   9/18/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123429   9/19/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123430   1/22/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123431   7/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123432   9/30/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123433   2/19/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123434   9/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123435  12/31/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123436  11/21/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123437   4/11/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123438    4/1/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123439  10/10/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123440  11/24/97  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123441    7/1/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 123442   4/16/98  10/11/16  A ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                151     152 153
# 0              NaN  CENTRE NaN
# 1              NaN  CENTRE NaN
# 2              NaN  CENTRE NaN
# 3              NaN  CENTRE NaN
# 4       5707687675  CENTRE NaN
# 5              NaN  CENTRE NaN
# 6              NaN  CENTRE NaN
# 7              NaN  CENTRE NaN
# 8              NaN  CENTRE NaN
# 9              NaN  CENTRE NaN
# 10      8145065538  CENTRE NaN
# 11             NaN  CENTRE NaN
# 12      6105098485  CENTRE NaN
# 13      8147691906  CENTRE NaN
# 14             NaN  CENTRE NaN
# 15             NaN  CENTRE NaN
# 16             NaN  CENTRE NaN
# 17      8143550831  CENTRE NaN
# 18             NaN  CENTRE NaN
# 19             NaN  CENTRE NaN
# 20      6108446630  CENTRE NaN
# 21         3530656  CENTRE NaN
# 22         3559388  CENTRE NaN
# 23         3559067  CENTRE NaN
# 24             NaN  CENTRE NaN
# 25         3553298  CENTRE NaN
# 26             NaN  CENTRE NaN
# 27             NaN  CENTRE NaN
# 28         3553569  CENTRE NaN
# 29             NaN  CENTRE NaN
# ...            ...     ...  ..
# 123413         NaN  CENTRE NaN
# 123414         NaN  CENTRE NaN
# 123415         NaN  CENTRE NaN
# 123416         NaN  CENTRE NaN
# 123417         NaN  CENTRE NaN
# 123418         NaN  CENTRE NaN
# 123419  5709005611  CENTRE NaN
# 123420         NaN  CENTRE NaN
# 123421         NaN  CENTRE NaN
# 123422  2036045055  CENTRE NaN
# 123423  2034614023  CENTRE NaN
# 123424         NaN  CENTRE NaN
# 123425  5709034112  CENTRE NaN
# 123426         NaN  CENTRE NaN
# 123427  5704179068  CENTRE NaN
# 123428  5709055297  CENTRE NaN
# 123429  9546629236  CENTRE NaN
# 123430  6306312989  CENTRE NaN
# 123431  5704368864  CENTRE NaN
# 123432         NaN  CENTRE NaN
# 123433         NaN  CENTRE NaN
# 123434  9732242161  CENTRE NaN
# 123435  7247775506  CENTRE NaN
# 123436  6309359977  CENTRE NaN
# 123437         NaN  CENTRE NaN
# 123438         NaN  CENTRE NaN
# 123439  6315594571  CENTRE NaN
# 123440         NaN  CENTRE NaN
# 123441         NaN  CENTRE NaN
# 123442         NaN  CENTRE NaN
#
# [123443 rows x 153 columns]

# %%
# pull out data for precinct 42
df_voters42 = df_voters.loc[df_voters['27'] == 42]
df_voters42
# Out:
#                   1    2            3          4          5    6    7  \
# 60899  001060962-14  NaN        MISKA   JENNIFER     SELLER  NaN    F
# 60900  001076841-14  NaN         DUNN    LORETTA          M  NaN    U
# 60901  001109561-14  NaN      BEECHAM       JANA   MICHELLE  NaN    F
# 60902  001304938-14  NaN      WELESKO       JOHN          P  NaN    M
# 60903  001350294-14  NaN      WELESKO    MAUREEN          A  NaN    F
# 60904  001352001-14  NaN         FREY    BARBARA          J  NaN    F
# 60905  001403271-14  NaN     ZARITSKI     THOMAS          M  NaN    M
# 60906  001516546-14  NaN       STONER      DIANE          M  NaN    F
# 60907  001554049-14  NaN       STONER    GREGORY       DEAN  NaN    M
# 60908  001594460-14  NaN     REICHART    KATHRYN          D  NaN    F
# 60909  002112536-14  NaN       SCHERF    KATHRYN    SUZANNE  NaN    F
# 60910  002129042-14  NaN      MARTIRE       LYNN          M  NaN    F
# 60911  002148957-14  NaN     FRIEDKEN   FLORINNE          I  NaN    F
# 60912  002180832-14  NaN        DAVIS      LUISE         K.  NaN    F
# 60913  002254163-14  NaN      JACKSON       RUTH        ANN  NaN    F
# 60914  002258051-14  NaN    ALEXANDER    CYNTHIA     DENISE  NaN    F
# 60915  002332616-14  NaN      HANCZAR    CYNTHIA          M  NaN    U
# 60916  002338063-14  NaN       MEEHAN      DAVID          E  NaN    M
# 60917  002342253-14  NaN       SALUGA     RONALD      HENRY  NaN    M
# 60918  002361732-14  NaN       TALONE    MICHAEL          J  NaN    M
# 60919  002376221-14  NaN        SHARP     GEORGE          R  NaN    M
# 60920  002376921-14  NaN        HANEY       JANE          T  NaN    F
# 60921  002503722-14  NaN      STEWART     MARTHA          M  NaN    F
# 60922  002609233-14  NaN        BARRY       SEAN    PATRICK  NaN    M
# 60923  002656707-14  NaN        ROHAN    CAROLYN       MARY  NaN    F
# 60919         NaN  CENTRE NaN
# 60920         NaN  CENTRE NaN
# 60921  8142377200  CENTRE NaN
# 60922         NaN  CENTRE NaN
# 60923  8142341033  CENTRE NaN
# 60924         NaN  CENTRE NaN
# 60925  8142383809  CENTRE NaN
# 60926         NaN  CENTRE NaN
# 60927         NaN  CENTRE NaN
# 60928         NaN  CENTRE NaN
# ...           ...     ...  ..
# 62985         NaN  CENTRE NaN
# 62986  8142320749  CENTRE NaN
# 62987  8148629087  CENTRE NaN
# 62988         NaN  CENTRE NaN
# 62989         NaN  CENTRE NaN
# 62990         NaN  CENTRE NaN
# 62991  8149337325  CENTRE NaN
# 62992         NaN  CENTRE NaN
# 62993  4434663203  CENTRE NaN
# 62994         NaN  CENTRE NaN
# 62995         NaN  CENTRE NaN
# 62996  3104069255  CENTRE NaN
# 62997  8148805146  CENTRE NaN
# 62998  8144042128  CENTRE NaN
# 62999  4127597662  CENTRE NaN
# 63000         NaN  CENTRE NaN
# 63001         NaN  CENTRE NaN
# 63002         NaN  CENTRE NaN
# 63003  8478046502  CENTRE NaN
# 63004  8144416811  CENTRE NaN
# 63005         NaN  CENTRE NaN
# 63006         NaN  CENTRE NaN
# 63007         NaN  CENTRE NaN
# 63008         NaN  CENTRE NaN
# 63009  8143804800  CENTRE NaN
# 63010         NaN  CENTRE NaN
# 63011         NaN  CENTRE NaN
# 63012  8149359003  CENTRE NaN
# 63013  8144046827  CENTRE NaN
# 63014         NaN  CENTRE NaN
#
# [2116 rows x 153 columns]

# %%
# group data by party subscriber and sum in a table
grouped = df_voters42.groupby('12') # Group by party registrations
summed = grouped['12'].count() # Get counts of each group
summed.sort_values(inplace=True, ascending=False)
df_summed = summed.to_frame()
df_summed.columns = ['NUMBER']
df_summed.index.names = ['PARTY']
df_summed

# group into three categories: republican, democrat and other
df_summed[(df_summed.index != 'D') & (df_summed.index != 'R')]
parties = ['Democrat', 'Republican', 'Other']
values = np.array([df_summed[(df_summed.index == 'D')].NUMBER.item(),df_summed[(df_summed.index == 'R')].NUMBER.item(),df_summed[(df_summed.index != 'D') & (df_summed.index != 'R')].NUMBER.sum()])
df_parties = pd.DataFrame(values,index=parties,columns=list('N'))
df_parties
# Out:
#               N
# Democrat    824
# Republican  978
# Other       314

# %%
# Read Election Results data and create a table for Precinct 42
df_results = pd.read_table('data/centrecounty_precinct_results_nov2016.txt', sep=',')
# Look at the data for precinct 42
df_results[df_results['PrecNo'] == 42]
# Out:
#                            County  ElecYear          Election  \
# 1576  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1577  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1578  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1579  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1580  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1581  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1582  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1583  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1584  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1585  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1586  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1587  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1588  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1589  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1590  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1591  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1592  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1593  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1594  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1595  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1596  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1597  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1598  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1599  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1600  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1601  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1602  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1603  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1604  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1605  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1606  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1607  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1608  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1609  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1610  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1611  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1612  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1613  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1614  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
#
#              ElecDate  PrecNo          PrecName               Party  \
# 1576  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1577  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1578  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1579  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1580  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1581  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH  CONSTITUTION PARTY
# 1582  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1583  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1584  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1585  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1586  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH  CONSTITUTION PARTY
# 1587  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1588  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1589  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1590  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1591  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1592  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1593  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1594  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1595  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1596  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1597  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1598  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1599  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1600  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1601  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1602  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1603  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1604  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1605  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1606  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1607  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1608  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1609  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1610  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1611  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1612  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1613  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1614  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
#
#                                                 Contest  Descr  \
# 1576                          REGISTERED VOTERS - TOTAL    NaN
# 1577                               BALLOTS CAST - TOTAL    NaN
# 1578                              VOTER TURNOUT - TOTAL    NaN
# 1579                                     STRAIGHT PARTY    NaN
# 1580                                     STRAIGHT PARTY    NaN
# 1581                                     STRAIGHT PARTY    NaN
# 1582                                     STRAIGHT PARTY    NaN
# 1583                                     STRAIGHT PARTY    NaN
# 1584                              PRESIDENTIAL ELECTORS    NaN
# 1585                              PRESIDENTIAL ELECTORS    NaN
# 1586                              PRESIDENTIAL ELECTORS    NaN
# 1587                              PRESIDENTIAL ELECTORS    NaN
# 1588                              PRESIDENTIAL ELECTORS    NaN
# 1589                              PRESIDENTIAL ELECTORS    NaN
# 1590                              UNITED STATES SENATOR    NaN
# 1591                              UNITED STATES SENATOR    NaN
# 1592                              UNITED STATES SENATOR    NaN
# 1593                              UNITED STATES SENATOR    NaN
# 1594                                   ATTORNEY GENERAL    NaN
# 1595                                   ATTORNEY GENERAL    NaN
# 1596                                   ATTORNEY GENERAL    NaN
# 1597                                    AUDITOR GENERAL    NaN
# 1598                                    AUDITOR GENERAL    NaN
# 1599                                    AUDITOR GENERAL    NaN
# 1600                                    AUDITOR GENERAL    NaN
# 1601                                    AUDITOR GENERAL    NaN
# 1602                                    STATE TREASURER    NaN
# 1603                                    STATE TREASURER    NaN
# 1604                                    STATE TREASURER    NaN
# 1605                                    STATE TREASURER    NaN
# 1606                                    STATE TREASURER    NaN
# 1607       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1608       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1609       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1610  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1611  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1612  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1613                                         JUDGES AGE    NaN
# 1614                                         JUDGES AGE    NaN
#
#                         VoteFor                     Candidate    Posn   Count  \
# 1576                        NaN                           NaN  3472.0  2097.0
# 1577                        NaN                           NaN  3473.0  1626.0
# 1578                        NaN                           NaN  3474.0     NaN
# 1579  VOTE FOR NOT MORE THAN  1                    DEMOCRATIC  3479.0   303.0
# 1580  VOTE FOR NOT MORE THAN  1                    REPUBLICAN  3480.0   358.0
# 1581  VOTE FOR NOT MORE THAN  1            CONSTITUTION PARTY  3481.0     0.0
# 1582  VOTE FOR NOT MORE THAN  1                         GREEN  3482.0     1.0
# 1583  VOTE FOR NOT MORE THAN  1                   LIBERTARIAN  3483.0     2.0
# 1584  VOTE FOR NOT MORE THAN  1   HILLARY CLINTON,  PRESIDENT  3488.0   802.0
# 1585  VOTE FOR NOT MORE THAN  1    DONALD J TRUMP,  PRESIDENT  3489.0   736.0
# 1586  VOTE FOR NOT MORE THAN  1  DARRELL L CASTLE,  PRESIDENT  3490.0     6.0
# 1587  VOTE FOR NOT MORE THAN  1        JILL STEIN,  PRESIDENT  3491.0    16.0
# 1588  VOTE FOR NOT MORE THAN  1       GARY JOHNSON, PRESIDENT  3492.0    34.0
# 1589  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3493.0    25.0
# 1590  VOTE FOR NOT MORE THAN  1                 KATIE MCGINTY  3498.0   751.0
# 1591  VOTE FOR NOT MORE THAN  1                    PAT TOOMEY  3499.0   801.0
# 1592  VOTE FOR NOT MORE THAN  1        EDWARD T CLIFFORD, III  3500.0    48.0
# 1593  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3501.0     0.0
# 1594  VOTE FOR NOT MORE THAN  1                  JOSH SHAPIRO  3506.0   778.0
# 1595  VOTE FOR NOT MORE THAN  1                 JOHN RAFFERTY  3507.0   806.0
# 1596  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3508.0     0.0
# 1597  VOTE FOR NOT MORE THAN  1           EUGENE A DEPASQUALE  3513.0   747.0
# 1598  VOTE FOR NOT MORE THAN  1                    JOHN BROWN  3514.0   739.0
# 1599  VOTE FOR NOT MORE THAN  1                JOHN J SWEENEY  3515.0    36.0
# 1600  VOTE FOR NOT MORE THAN  1                   ROY A MINET  3516.0    37.0
# 1601  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3517.0     1.0
# 1602  VOTE FOR NOT MORE THAN  1                  JOE TORSELLA  3522.0   741.0
# 1603  VOTE FOR NOT MORE THAN  1                     OTTO VOIT  3523.0   736.0
# 1604  VOTE FOR NOT MORE THAN  1                 KRISTIN COMBS  3524.0    46.0
# 1605  VOTE FOR NOT MORE THAN  1                    JAMES BABB  3525.0    31.0
# 1606  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3526.0     1.0
# 1607  VOTE FOR NOT MORE THAN  1          KERITH STRANO TAYLOR  3530.0   711.0
# 1608  VOTE FOR NOT MORE THAN  1             GLENN GT THOMPSON  3531.0   867.0
# 1609  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3532.0     1.0
# 1610  VOTE FOR NOT MORE THAN  1                MELODY S FLECK  3537.0   635.0
# 1611  VOTE FOR NOT MORE THAN  1           KERRY A BENNINGHOFF  3538.0   941.0
# 1612  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3539.0     0.0
# 1613  VOTE FOR NOT MORE THAN  1                           YES  3544.0   683.0
# 1614  VOTE FOR NOT MORE THAN  1                            NO  3545.0   615.0
#
#       PctCnt  Total  PctTot
# 1576     NaN    NaN     NaN
# 1577     NaN    NaN     NaN
# 1578   77.54    NaN     NaN
# 1579   45.63    NaN     NaN
# 1580   53.92    NaN     NaN
# 1581     NaN    NaN     NaN
# 1582    0.15    NaN     NaN
# 1583    0.30    NaN     NaN
# 1584   49.54    NaN     NaN
# 1585   45.46    NaN     NaN
# 1586    0.37    NaN     NaN
# 1587    0.99    NaN     NaN
# 1588    2.10    NaN     NaN
# 1589    1.54    NaN     NaN
# 1590   46.94    NaN     NaN
# 1591   50.06    NaN     NaN
# 1592    3.00    NaN     NaN
# 1593     NaN    NaN     NaN
# 1594   49.12    NaN     NaN
# 1595   50.88    NaN     NaN
# 1596     NaN    NaN     NaN
# 1597   47.88    NaN     NaN
# 1598   47.37    NaN     NaN
# 1599    2.31    NaN     NaN
# 1600    2.37    NaN     NaN
# 1601    0.06    NaN     NaN
# 1602   47.65    NaN     NaN
# 1603   47.33    NaN     NaN
# 1604    2.96    NaN     NaN
# 1605    1.99    NaN     NaN
# 1606    0.06    NaN     NaN
# 1607   45.03    NaN     NaN
# 1608   54.91    NaN     NaN
# 1609    0.06    NaN     NaN
# 1610   40.29    NaN     NaN
# 1611   59.71    NaN     NaN
# 1612     NaN    NaN     NaN
# 1613   52.62    NaN     NaN
# 1614   47.38    NaN     NaN

# %%
# pull out data for precinct 42
df_results42 = df_results.loc[df_results['PrecNo'] == 42]
df_results42
# Out:
#                            County  ElecYear          Election  \
# 1576  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1577  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1578  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1579  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1580  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1581  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1582  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1583  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1584  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1585  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1586  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1587  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1588  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1589  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1590  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1591  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1592  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1593  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1594  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1595  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1596  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1597  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1598  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1599  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1600  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1601  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1602  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1603  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1604  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1605  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1606  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1607  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1608  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1609  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1610  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1611  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1612  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1613  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1614  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
#
#              ElecDate  PrecNo          PrecName               Party  \
# 1576  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1577  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1578  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1579  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1580  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1581  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH  CONSTITUTION PARTY
# 1582  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1583  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1584  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1585  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1586  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH  CONSTITUTION PARTY
# 1587  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1588  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1589  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1590  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1591  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1592  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1593  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1594  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1595  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1596  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1597  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1598  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1599  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1600  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1601  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1602  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1603  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1604  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1605  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
# 1606  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1607  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1608  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1609  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1610  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1611  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1612  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1613  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
# 1614  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH                 NaN
#
#                                                 Contest  Descr  \
# 1576                          REGISTERED VOTERS - TOTAL    NaN
# 1577                               BALLOTS CAST - TOTAL    NaN
# 1578                              VOTER TURNOUT - TOTAL    NaN
# 1579                                     STRAIGHT PARTY    NaN
# 1580                                     STRAIGHT PARTY    NaN
# 1581                                     STRAIGHT PARTY    NaN
# 1582                                     STRAIGHT PARTY    NaN
# 1583                                     STRAIGHT PARTY    NaN
# 1584                              PRESIDENTIAL ELECTORS    NaN
# 1585                              PRESIDENTIAL ELECTORS    NaN
# 1586                              PRESIDENTIAL ELECTORS    NaN
# 1587                              PRESIDENTIAL ELECTORS    NaN
# 1588                              PRESIDENTIAL ELECTORS    NaN
# 1589                              PRESIDENTIAL ELECTORS    NaN
# 1590                              UNITED STATES SENATOR    NaN
# 1591                              UNITED STATES SENATOR    NaN
# 1592                              UNITED STATES SENATOR    NaN
# 1593                              UNITED STATES SENATOR    NaN
# 1594                                   ATTORNEY GENERAL    NaN
# 1595                                   ATTORNEY GENERAL    NaN
# 1596                                   ATTORNEY GENERAL    NaN
# 1597                                    AUDITOR GENERAL    NaN
# 1598                                    AUDITOR GENERAL    NaN
# 1599                                    AUDITOR GENERAL    NaN
# 1600                                    AUDITOR GENERAL    NaN
# 1601                                    AUDITOR GENERAL    NaN
# 1602                                    STATE TREASURER    NaN
# 1603                                    STATE TREASURER    NaN
# 1604                                    STATE TREASURER    NaN
# 1605                                    STATE TREASURER    NaN
# 1606                                    STATE TREASURER    NaN
# 1607       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1608       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1609       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 1610  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1611  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1612  REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...    NaN
# 1613                                         JUDGES AGE    NaN
# 1614                                         JUDGES AGE    NaN
#
#                         VoteFor                     Candidate    Posn   Count  \
# 1576                        NaN                           NaN  3472.0  2097.0
# 1577                        NaN                           NaN  3473.0  1626.0
# 1578                        NaN                           NaN  3474.0     NaN
# 1579  VOTE FOR NOT MORE THAN  1                    DEMOCRATIC  3479.0   303.0
# 1580  VOTE FOR NOT MORE THAN  1                    REPUBLICAN  3480.0   358.0
# 1586    0.37    NaN     NaN
# 1587    0.99    NaN     NaN
# 1588    2.10    NaN     NaN
# 1589    1.54    NaN     NaN
# 1590   46.94    NaN     NaN
# 1591   50.06    NaN     NaN
# 1592    3.00    NaN     NaN
# 1593     NaN    NaN     NaN
# 1594   49.12    NaN     NaN
# 1595   50.88    NaN     NaN
# 1596     NaN    NaN     NaN
# 1597   47.88    NaN     NaN
# 1598   47.37    NaN     NaN
# 1599    2.31    NaN     NaN
# 1600    2.37    NaN     NaN
# 1601    0.06    NaN     NaN
# 1602   47.65    NaN     NaN
# 1603   47.33    NaN     NaN
# 1604    2.96    NaN     NaN
# 1605    1.99    NaN     NaN
# 1606    0.06    NaN     NaN
# 1607   45.03    NaN     NaN
# 1608   54.91    NaN     NaN
# 1609    0.06    NaN     NaN
# 1610   40.29    NaN     NaN
# 1611   59.71    NaN     NaN
# 1612     NaN    NaN     NaN
# 1613   52.62    NaN     NaN
# 1614   47.38    NaN     NaN

# %%
df_pres42 = df_results42.loc[df_results42['Contest'] == 'PRESIDENTIAL ELECTORS']
df_pres42.head()
# Out:
#                            County  ElecYear          Election  \
# 1584  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1585  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1586  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1587  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 1588  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
#
#              ElecDate  PrecNo          PrecName               Party  \
# 1584  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          DEMOCRATIC
# 1585  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH          REPUBLICAN
# 1586  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH  CONSTITUTION PARTY
# 1587  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH               GREEN
# 1588  NOVEMBER 8 2016    42.0  42 COLLEGE SOUTH         LIBERTARIAN
#
#                     Contest  Descr                    VoteFor  \
# 1584  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 1585  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 1586  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 1587  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 1588  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
#
#                          Candidate    Posn  Count  PctCnt  Total  PctTot
# 1584   HILLARY CLINTON,  PRESIDENT  3488.0  802.0   49.54    NaN     NaN
# 1585    DONALD J TRUMP,  PRESIDENT  3489.0  736.0   45.46    NaN     NaN
# 1586  DARRELL L CASTLE,  PRESIDENT  3490.0    6.0    0.37    NaN     NaN
# 1587        JILL STEIN,  PRESIDENT  3491.0   16.0    0.99    NaN     NaN
# 1588       GARY JOHNSON, PRESIDENT  3492.0   34.0    2.10    NaN     NaN

# %%
# sum by candidate and convert to integer
summed_pres = df_pres42.groupby('Candidate').Count.sum().astype(int)
summed_pres
# Out:
# Candidate
# DARRELL L CASTLE,  PRESIDENT      6
# DONALD J TRUMP,  PRESIDENT      736
# GARY JOHNSON, PRESIDENT          34
# HILLARY CLINTON,  PRESIDENT     802
# JILL STEIN,  PRESIDENT           16
# WRITE-IN                         25
# Name: Count, dtype: int64

# %%
# convert to dataframe
df_summed_pres = summed_pres.to_frame().astype(int)
df_summed_pres.columns = ['VOTES']
df_summed_pres.index.names = ['CANDIDATE']
print(df_summed_pres.values)
df_summed_pres
# Out:
# [[  6]
#  [736]
#  [ 34]
#  [802]
#  [ 16]
#  [ 25]]
#                               VOTES
# CANDIDATE
# DARRELL L CASTLE,  PRESIDENT      6
# DONALD J TRUMP,  PRESIDENT      736
# GARY JOHNSON, PRESIDENT          34
# HILLARY CLINTON,  PRESIDENT     802
# JILL STEIN,  PRESIDENT           16
# WRITE-IN                         25

# %%
# group into three categories: republican, democrat and other
df_summed_pres[(df_summed_pres.index != 'HILLARY CLINTON, PRESIDENT') & (df_summed_pres.index != 'DONALD J TRUMP, PRESIDENT')]
presparty = ['Democrat', 'Republican', 'Other']
presvalues = np.array([df_summed_pres[(df_summed_pres.index == 'HILLARY CLINTON,  PRESIDENT')].VOTES.item(),df_summed_pres[(df_summed_pres.index == 'DONALD J TRUMP,  PRESIDENT')].VOTES.item(),df_summed_pres[(df_summed_pres.index != 'HILLARY CLINTON,  PRESIDENT') & (df_summed_pres.index != 'DONALD J TRUMP,  PRESIDENT')].VOTES.sum()])
print(presvalues)
df_presparty = pd.DataFrame(presvalues,index=presparty,columns=list('V'))
df_presparty
# Out:
# [802 736  81]
#               V
# Democrat    802
# Republican  736
# Other        81

# %%
# run a join!
df_compare = df_parties.join(df_presparty, lsuffix='N', rsuffix='V')
df_compare.index.names = ['Party']
df_compare
# Out:
#               N    V
# Party
# Democrat    824  802
# Republican  978  736
# Other       314   81

# %%
# Chart the dataset

# Set the positions and width of the bars, and plot them
pos = list(range(len(df_compare['N'])))
width = 0.25
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar with registration ('N') data, in position pos,
plt.bar(pos,df_compare['N'], width, alpha=0.5, color='#96c7ac')

# Create a bar with voting ('V') data, in position pos + some width buffer,
plt.bar([p + width for p in pos], df_compare['V'], width, alpha=0.5, color='#8e374d')

# Label the chart & axes, and add a legend
ax.set_ylabel('Number of People', fontsize=18)
ax.set_xlabel('Political Party', fontsize=20)
ax.set_title('2016 Presidential Election Voter Registration & Election Results by Party in Pennsylvania Precinct 42', fontsize=20)
plt.legend(['Registered Voters', 'Ballots Cast'], loc='upper right')

# Position & label the x ticks
ax.set_xticks([p + .5 * width for p in pos])
ax.set_xticklabels(df_compare.index, fontsize=15)

# Set x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*3)
plt.ylim([0, 1200])

plt.show()

# %% [markdown]
# ## Part 2 - Scatterplotting
#
# Now we will use the **precinct_centroids** file provided to display the geographical location of the centroid of each precinct, plot them in a scatterplot, then size the points in the scatterplot according to the number of votes.
#
# First, load the CSV.

# %%
df_precinct_locations = pd.read_table('data/center_county_precinct_centroids.csv', sep=',', low_memory=False)
df_precinct_locations.head()
# Out:
#            X          Y  OBJECTID        NAME  Precinct  \
# 0 -77.972391  41.129340         1    BURNSIDE        40
# 1 -77.641414  41.068505         2     LIBERTY        60
# 2 -77.688090  41.010310         3  HOWARD TWP        58
# 3 -77.642348  40.985981         4      MARION        61
# 4 -77.949892  41.027568         5   SNOW SHOE        14
#
#                                  GlobalID      MDJ    ShapeSTAre  \
# 0  {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 1  {57577111-D7B7-4048-9517-EF2ED6059928}  49-3-02  6.878831e+08
# 2  {C9B8B5CF-6699-485A-97D2-74FB9B2D6FFE}  49-3-02  5.275320e+08
# 3  {FA3740D2-624B-4464-B6CD-16F6E219ADEA}  49-3-02  6.135493e+08
# 4  {908F092A-BCFF-4EA5-99D7-B9248A2EA56A}  49-3-03  1.644442e+07
#
#       ShapeSTLen
# 0  280069.560289
# 1  131265.443714
# 2  111072.612891
# 3  131038.017743
# 4   19920.287608

# %% [markdown]
# Now that we have a new `DataFrame` for each precinct and the geographical location of its centroid, we can use lat/lon values to create a scatter plot. We can even vary their size based on the variables or criteria we set. If variation across precincts is not that big, we can use a log function to better visualize it on our plot. Numpy has a quick log implementation:
# ```Python
# np.log(value)
# ```
# In this following example, we give the points a simple size of 25.

# %%
plt.scatter(df_precinct_locations['X'],df_precinct_locations['Y'], s=25)
plt.show()

# %% [markdown]
# **Problem 4: Using the above example, and the documentation on scatterplots, create two scatterplots using longitude and latitude X and Y locations, one showing percentage of vote for Trump, and other percentage of vote for Clinton. Make the Trump dots colored red, and Clinton blue.**
#
# Find the [Scatterplot documentation here](http://pandas.pydata.org/pandas-docs/version/0.19.1/visualization.html#scatter-plot)
#
# Hint: You will need to join the results precincts file to the centroids, and then set the size of the plot points to be the percentages. This is accessed using the S property.
#
# To perform the join, use merge. This [Stack Exchange](http://stackoverflow.com/questions/20375561/joining-pandas-dataframes-by-column-names) question will help!

# %%
# read in the election results
df_results = pd.read_table('data/centrecounty_precinct_results_nov2016.txt', sep=',')
df_results.head()
# Out:
#                         County  ElecYear          Election         ElecDate  \
# 0  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 1  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 2  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 3  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 4  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#    PrecNo             PrecName       Party                    Contest  Descr  \
# 0     1.0  01 BELLEFONTE NORTH         NaN  REGISTERED VOTERS - TOTAL    NaN
# 1     1.0  01 BELLEFONTE NORTH         NaN       BALLOTS CAST - TOTAL    NaN
# 2     1.0  01 BELLEFONTE NORTH         NaN      VOTER TURNOUT - TOTAL    NaN
# 3     1.0  01 BELLEFONTE NORTH  DEMOCRATIC             STRAIGHT PARTY    NaN
# 4     1.0  01 BELLEFONTE NORTH  REPUBLICAN             STRAIGHT PARTY    NaN
#
#                      VoteFor   Candidate  Posn  Count  PctCnt  Total  PctTot
# 0                        NaN         NaN  10.0  507.0     NaN    NaN     NaN
# 1                        NaN         NaN  11.0  391.0     NaN    NaN     NaN
# 2                        NaN         NaN  12.0    NaN   77.12    NaN     NaN
# 3  VOTE FOR NOT MORE THAN  1  DEMOCRATIC  17.0   46.0   40.35    NaN     NaN
# 4  VOTE FOR NOT MORE THAN  1  REPUBLICAN  18.0   66.0   57.89    NaN     NaN

# %%
# merge the two datasets on precinct
df_merge = pd.merge(df_precinct_locations, df_results, left_on = 'Precinct', right_on = 'PrecNo')
# 3513 -77.798666  40.868055        43  BENNER SOUTH        37
# 3514 -77.798666  40.868055        43  BENNER SOUTH        37
# 3515 -77.798666  40.868055        43  BENNER SOUTH        37
# 3516 -77.798666  40.868055        43  BENNER SOUTH        37
# 3517 -77.798666  40.868055        43  BENNER SOUTH        37
# 3518 -77.798666  40.868055        43  BENNER SOUTH        37
# 3519 -77.798666  40.868055        43  BENNER SOUTH        37
#
#                                     GlobalID      MDJ    ShapeSTAre  \
# 0     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 1     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 2     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 3     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 4     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 5     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 6     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 7     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 8     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 9     {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 10    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 11    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 12    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 13    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 14    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 15    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 16    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 17    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 18    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 19    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 20    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 21    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 22    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 23    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 24    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 25    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 26    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 27    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 28    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 29    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# ...                                      ...      ...           ...
# 3490  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3491  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3492  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3493  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3494  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3495  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3496  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3497  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3498  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3499  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3500  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3501  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3502  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3503  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3504  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3505  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3506  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3507  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3508  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3509  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3510  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3511  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3512  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3513  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3514  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3515  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3516  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3517  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3518  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
# 3519  {7112D0E1-92C3-44B6-81E0-EFBD3DE7BC23}  49-3-02  5.434501e+08
#
#          ShapeSTLen                       County  ...                 Party  \
# 0     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 1     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 2     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 4     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 5     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...    CONSTITUTION PARTY
# 6     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 7     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 8     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 9     280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 10    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...    CONSTITUTION PARTY
# 11    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 12    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 13    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 14    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 15    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 16    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 17    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 18    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 19    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 20    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 21    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 22    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 23    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 24    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 25    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 26    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 27    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 28    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 29    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# ...             ...                          ...  ...                   ...
# 3490  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3491  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...    CONSTITUTION PARTY
# 3492  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 3493  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 3494  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3495  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3496  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3497  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 3498  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3499  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3500  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3501  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3502  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3503  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3504  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 3505  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 3506  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3507  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3508  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3509  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 3510  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
# 3511  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3512  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3513  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3514  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3515  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 3516  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 3517  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3518  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
# 3519  145412.096258  CENTRE COUNTY, PENNSYLVANIA  ...                   NaN
#
#                                                 Contest Descr  \
# 0                             REGISTERED VOTERS - TOTAL   NaN
# 1                                  BALLOTS CAST - TOTAL   NaN
# 2                                 VOTER TURNOUT - TOTAL   NaN
# 3                                        STRAIGHT PARTY   NaN
# 4                                        STRAIGHT PARTY   NaN
# 5                                        STRAIGHT PARTY   NaN
# 6                                        STRAIGHT PARTY   NaN
# 7                                        STRAIGHT PARTY   NaN
# 8                                 PRESIDENTIAL ELECTORS   NaN
# 9                                 PRESIDENTIAL ELECTORS   NaN
# 10                                PRESIDENTIAL ELECTORS   NaN
# 11                                PRESIDENTIAL ELECTORS   NaN
# 12                                PRESIDENTIAL ELECTORS   NaN
# 13                                PRESIDENTIAL ELECTORS   NaN
# 14                                UNITED STATES SENATOR   NaN
# 15                                UNITED STATES SENATOR   NaN
# 16                                UNITED STATES SENATOR   NaN
# 17                                UNITED STATES SENATOR   NaN
# 18                                     ATTORNEY GENERAL   NaN
# 19                                     ATTORNEY GENERAL   NaN
# 20                                     ATTORNEY GENERAL   NaN
# 21                                      AUDITOR GENERAL   NaN
# 22                                      AUDITOR GENERAL   NaN
# 23                                      AUDITOR GENERAL   NaN
# 24                                      AUDITOR GENERAL   NaN
# 25                                      AUDITOR GENERAL   NaN
# 26                                      STATE TREASURER   NaN
# 27                                      STATE TREASURER   NaN
# 28                                      STATE TREASURER   NaN
# 29                                      STATE TREASURER   NaN
# ...                                                 ...   ...
# 3490                              PRESIDENTIAL ELECTORS   NaN
# 3491                              PRESIDENTIAL ELECTORS   NaN
# 3492                              PRESIDENTIAL ELECTORS   NaN
# 3493                              PRESIDENTIAL ELECTORS   NaN
# 3494                              PRESIDENTIAL ELECTORS   NaN
# 3495                              UNITED STATES SENATOR   NaN
# 3496                              UNITED STATES SENATOR   NaN
# 3497                              UNITED STATES SENATOR   NaN
# 3498                              UNITED STATES SENATOR   NaN
# 3499                                   ATTORNEY GENERAL   NaN
# 3500                                   ATTORNEY GENERAL   NaN
# 3501                                   ATTORNEY GENERAL   NaN
# 3502                                    AUDITOR GENERAL   NaN
# 3503                                    AUDITOR GENERAL   NaN
# 3504                                    AUDITOR GENERAL   NaN
# 3505                                    AUDITOR GENERAL   NaN
# 3506                                    AUDITOR GENERAL   NaN
# 3507                                    STATE TREASURER   NaN
# 3508                                    STATE TREASURER   NaN
# 3509                                    STATE TREASURER   NaN
# 3510                                    STATE TREASURER   NaN
# 3511                                    STATE TREASURER   NaN
# 3512       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL   NaN
# 3513       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL   NaN
# 3514       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL   NaN
# 3515  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...   NaN
# 3516  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...   NaN
# 3517  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...   NaN
# 3518                                         JUDGES AGE   NaN
# 3519                                         JUDGES AGE   NaN
#
#                         VoteFor                     Candidate    Posn  Count  \
# 0                           NaN                           NaN  3302.0  261.0
# 1                           NaN                           NaN  3303.0  206.0
# 2                           NaN                           NaN  3304.0    NaN
# 3     VOTE FOR NOT MORE THAN  1                    DEMOCRATIC  3309.0   13.0
# 4     VOTE FOR NOT MORE THAN  1                    REPUBLICAN  3310.0   44.0
# 5     VOTE FOR NOT MORE THAN  1            CONSTITUTION PARTY  3311.0    1.0
# 6     VOTE FOR NOT MORE THAN  1                         GREEN  3312.0    0.0
# 7     VOTE FOR NOT MORE THAN  1                   LIBERTARIAN  3313.0    0.0
# 8     VOTE FOR NOT MORE THAN  1   HILLARY CLINTON,  PRESIDENT  3318.0   45.0
# 9     VOTE FOR NOT MORE THAN  1    DONALD J TRUMP,  PRESIDENT  3319.0  157.0
# 10    VOTE FOR NOT MORE THAN  1  DARRELL L CASTLE,  PRESIDENT  3320.0    0.0
# 11    VOTE FOR NOT MORE THAN  1        JILL STEIN,  PRESIDENT  3321.0    0.0
# 12    VOTE FOR NOT MORE THAN  1       GARY JOHNSON, PRESIDENT  3322.0    2.0
# 13    VOTE FOR NOT MORE THAN  1                      WRITE-IN  3323.0    1.0
# 14    VOTE FOR NOT MORE THAN  1                 KATIE MCGINTY  3328.0   52.0
# 15    VOTE FOR NOT MORE THAN  1                    PAT TOOMEY  3329.0  135.0
# 16    VOTE FOR NOT MORE THAN  1        EDWARD T CLIFFORD, III  3330.0   16.0
# 17    VOTE FOR NOT MORE THAN  1                      WRITE-IN  3331.0    0.0
# 18    VOTE FOR NOT MORE THAN  1                  JOSH SHAPIRO  3336.0   65.0
# 19    VOTE FOR NOT MORE THAN  1                 JOHN RAFFERTY  3337.0  136.0
# 20    VOTE FOR NOT MORE THAN  1                      WRITE-IN  3338.0    0.0
# 21    VOTE FOR NOT MORE THAN  1           EUGENE A DEPASQUALE  3343.0   60.0
# 22    VOTE FOR NOT MORE THAN  1                    JOHN BROWN  3344.0  131.0
# 23    VOTE FOR NOT MORE THAN  1                JOHN J SWEENEY  3345.0    3.0
# 24    VOTE FOR NOT MORE THAN  1                   ROY A MINET  3346.0    3.0
# 25    VOTE FOR NOT MORE THAN  1                      WRITE-IN  3347.0    0.0
# 26    VOTE FOR NOT MORE THAN  1                  JOE TORSELLA  3352.0   58.0
# 27    VOTE FOR NOT MORE THAN  1                     OTTO VOIT  3353.0  117.0
# 28    VOTE FOR NOT MORE THAN  1                 KRISTIN COMBS  3354.0   13.0
# 29    VOTE FOR NOT MORE THAN  1                    JAMES BABB  3355.0    8.0
# ...                         ...                           ...     ...    ...
# 3490  VOTE FOR NOT MORE THAN  1    DONALD J TRUMP,  PRESIDENT  3064.0  821.0
# 3491  VOTE FOR NOT MORE THAN  1  DARRELL L CASTLE,  PRESIDENT  3065.0    5.0
# 3492  VOTE FOR NOT MORE THAN  1        JILL STEIN,  PRESIDENT  3066.0    8.0
# 3493  VOTE FOR NOT MORE THAN  1       GARY JOHNSON, PRESIDENT  3067.0   32.0
# 3494  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3068.0   18.0
# 3495  VOTE FOR NOT MORE THAN  1                 KATIE MCGINTY  3073.0  489.0
# 3496  VOTE FOR NOT MORE THAN  1                    PAT TOOMEY  3074.0  783.0
# 3497  VOTE FOR NOT MORE THAN  1        EDWARD T CLIFFORD, III  3075.0   84.0
# 3498  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3076.0    2.0
# 3499  VOTE FOR NOT MORE THAN  1                  JOSH SHAPIRO  3081.0  536.0
# 3500  VOTE FOR NOT MORE THAN  1                 JOHN RAFFERTY  3082.0  804.0
# 3501  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3083.0    3.0
# 3502  VOTE FOR NOT MORE THAN  1           EUGENE A DEPASQUALE  3088.0  550.0
# 3503  VOTE FOR NOT MORE THAN  1                    JOHN BROWN  3089.0  701.0
# 3504  VOTE FOR NOT MORE THAN  1                JOHN J SWEENEY  3090.0   42.0
# 3505  VOTE FOR NOT MORE THAN  1                   ROY A MINET  3091.0   35.0
# 3506  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3092.0    0.0
# 3507  VOTE FOR NOT MORE THAN  1                  JOE TORSELLA  3097.0  550.0
# 3508  VOTE FOR NOT MORE THAN  1                     OTTO VOIT  3098.0  688.0
# 3509  VOTE FOR NOT MORE THAN  1                 KRISTIN COMBS  3099.0   49.0
# 3510  VOTE FOR NOT MORE THAN  1                    JAMES BABB  3100.0   35.0
# 3511  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3101.0    1.0
# 3512  VOTE FOR NOT MORE THAN  1          KERITH STRANO TAYLOR  3105.0  431.0
# 3513  VOTE FOR NOT MORE THAN  1             GLENN GT THOMPSON  3106.0  913.0
# 3514  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3107.0    1.0
# 3515  VOTE FOR NOT MORE THAN  1                    MIKE HANNA  3112.0  690.0
# 3516  VOTE FOR NOT MORE THAN  1            STEPHANIE BOROWICZ  3113.0  652.0
# 3517  VOTE FOR NOT MORE THAN  1                      WRITE-IN  3114.0    0.0
# 3518  VOTE FOR NOT MORE THAN  1                           YES  3119.0  583.0
# 3519  VOTE FOR NOT MORE THAN  1                            NO  3120.0  604.0
#
#       PctCnt Total PctTot
# 0        NaN   NaN    NaN
# 1        NaN   NaN    NaN
# 2      78.93   NaN    NaN
# 3      22.41   NaN    NaN
# 4      75.86   NaN    NaN
# 5       1.72   NaN    NaN
# 6        NaN   NaN    NaN
# 7        NaN   NaN    NaN
# 8      21.95   NaN    NaN
# 9      76.59   NaN    NaN
# 10       NaN   NaN    NaN
# 11       NaN   NaN    NaN
# 12      0.98   NaN    NaN
# 13      0.49   NaN    NaN
# 14     25.62   NaN    NaN
# 15     66.50   NaN    NaN
# 16      7.88   NaN    NaN
# 17       NaN   NaN    NaN
# 18     32.34   NaN    NaN
# 19     67.66   NaN    NaN
# 20       NaN   NaN    NaN
# 21     30.46   NaN    NaN
# 22     66.50   NaN    NaN
# 23      1.52   NaN    NaN
# 24      1.52   NaN    NaN
# 25       NaN   NaN    NaN
# 26     29.59   NaN    NaN
# 27     59.69   NaN    NaN
# 28      6.63   NaN    NaN
# 29      4.08   NaN    NaN
# ...      ...   ...    ...
# 3490   60.10   NaN    NaN
# 3491    0.37   NaN    NaN
# 3492    0.59   NaN    NaN
# 3493    2.34   NaN    NaN
# 3494    1.32   NaN    NaN
# 3495   36.01   NaN    NaN
# 3496   57.66   NaN    NaN
# 3497    6.19   NaN    NaN
# 3498    0.15   NaN    NaN
# 3499   39.91   NaN    NaN
# 3500   59.87   NaN    NaN
# 3501    0.22   NaN    NaN
# 3502   41.42   NaN    NaN
# 3503   52.79   NaN    NaN
# 3504    3.16   NaN    NaN
# 3505    2.64   NaN    NaN
# 3506     NaN   NaN    NaN
# 3507   41.57   NaN    NaN
# 3508   52.00   NaN    NaN
# 3509    3.70   NaN    NaN
# 3510    2.65   NaN    NaN
# 3511    0.08   NaN    NaN
# 3512   32.04   NaN    NaN
# 3513   67.88   NaN    NaN
# 3514    0.07   NaN    NaN
# 3515   51.42   NaN    NaN
# 3516   48.58   NaN    NaN
# 3517     NaN   NaN    NaN
# 3518   49.12   NaN    NaN
# 3519   50.88   NaN    NaN
#
# [3520 rows x 25 columns]

# %%
# query to pull out just the presidential election
df_pres = df_merge.loc[df_merge['Contest'] == 'PRESIDENTIAL ELECTORS']
df_pres.head()
# Out:
#             X         Y  OBJECTID      NAME  Precinct  \
# 8  -77.972391  41.12934         1  BURNSIDE        40
# 9  -77.972391  41.12934         1  BURNSIDE        40
# 10 -77.972391  41.12934         1  BURNSIDE        40
# 11 -77.972391  41.12934         1  BURNSIDE        40
# 12 -77.972391  41.12934         1  BURNSIDE        40
#
#                                   GlobalID      MDJ    ShapeSTAre  \
# 8   {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 9   {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 10  {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 11  {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 12  {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
#
#        ShapeSTLen                       County  ...                 Party  \
# 8   280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            DEMOCRATIC
# 9   280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...            REPUBLICAN
# 10  280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...    CONSTITUTION PARTY
# 11  280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...                 GREEN
# 12  280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...           LIBERTARIAN
#
#                   Contest Descr                    VoteFor  \
# 8   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 9   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 10  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 11  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 12  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
#
#                        Candidate    Posn  Count  PctCnt Total PctTot
# 8    HILLARY CLINTON,  PRESIDENT  3318.0   45.0   21.95   NaN    NaN
# 9     DONALD J TRUMP,  PRESIDENT  3319.0  157.0   76.59   NaN    NaN
# 10  DARRELL L CASTLE,  PRESIDENT  3320.0    0.0     NaN   NaN    NaN
# 11        JILL STEIN,  PRESIDENT  3321.0    0.0     NaN   NaN    NaN
# 12       GARY JOHNSON, PRESIDENT  3322.0    2.0    0.98   NaN    NaN
#
# [5 rows x 25 columns]

# %%
# Map 1: Votes for Trump
# select for just Trump voter data
df_trump = df_pres.loc[df_merge['Candidate'] == 'DONALD J TRUMP,  PRESIDENT']
df_trump.head()
# Out:
#              X          Y  OBJECTID        NAME  Precinct  \
# 9   -77.972391  41.129340         1    BURNSIDE        40
# 48  -77.641414  41.068505         2     LIBERTY        60
# 87  -77.688090  41.010310         3  HOWARD TWP        58
# 126 -77.642348  40.985981         4      MARION        61
# 165 -77.949892  41.027568         5   SNOW SHOE        14
#
#                                    GlobalID      MDJ    ShapeSTAre  \
# 9    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 48   {57577111-D7B7-4048-9517-EF2ED6059928}  49-3-02  6.878831e+08
# 87   {C9B8B5CF-6699-485A-97D2-74FB9B2D6FFE}  49-3-02  5.275320e+08
# 126  {FA3740D2-624B-4464-B6CD-16F6E219ADEA}  49-3-02  6.135493e+08
# 165  {908F092A-BCFF-4EA5-99D7-B9248A2EA56A}  49-3-03  1.644442e+07
#
#         ShapeSTLen                       County  ...         Party  \
# 9    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...    REPUBLICAN
# 48   131265.443714  CENTRE COUNTY, PENNSYLVANIA  ...    REPUBLICAN
# 87   111072.612891  CENTRE COUNTY, PENNSYLVANIA  ...    REPUBLICAN
# 126  131038.017743  CENTRE COUNTY, PENNSYLVANIA  ...    REPUBLICAN
# 165   19920.287608  CENTRE COUNTY, PENNSYLVANIA  ...    REPUBLICAN
#
#                    Contest Descr                    VoteFor  \
# 9    PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 48   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 87   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 126  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 165  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
#
#                       Candidate    Posn  Count  PctCnt Total PctTot
# 9    DONALD J TRUMP,  PRESIDENT  3319.0  157.0   76.59   NaN    NaN
# 48   DONALD J TRUMP,  PRESIDENT  5023.0  557.0   71.50   NaN    NaN
# 87   DONALD J TRUMP,  PRESIDENT  4854.0  350.0   72.31   NaN    NaN
# 126  DONALD J TRUMP,  PRESIDENT  5108.0  347.0   68.44   NaN    NaN
# 165  DONALD J TRUMP,  PRESIDENT  1129.0  236.0   71.73   NaN    NaN
#
# [5 rows x 25 columns]

# %%
# Scatter Plot for Trump
plt.scatter(df_trump['X'],df_trump['Y'], s=df_trump['PctCnt']**1.15, color = '#b10000')
plt.suptitle('Pennsylvania Precinct Vote Percent Count for Trump by Precinct Longitude and Latitude', fontsize=20)
plt.xlabel('longitude', fontsize=16)
plt.ylabel('latitude', fontsize=16)
plt.show()

# %%
# Map 2: Votes for Clinton
# Add your code below:
df_clinton = df_pres.loc[df_merge['Candidate'] == 'HILLARY CLINTON,  PRESIDENT']
df_clinton.head()
# Out:
#              X          Y  OBJECTID        NAME  Precinct  \
# 8   -77.972391  41.129340         1    BURNSIDE        40
# 47  -77.641414  41.068505         2     LIBERTY        60
# 86  -77.688090  41.010310         3  HOWARD TWP        58
# 125 -77.642348  40.985981         4      MARION        61
# 164 -77.949892  41.027568         5   SNOW SHOE        14
#
#                                    GlobalID      MDJ    ShapeSTAre  \
# 8    {A309C3DE-8AD8-46A5-B8EA-B8F7E1ADB972}  49-3-03  2.530029e+09
# 47   {57577111-D7B7-4048-9517-EF2ED6059928}  49-3-02  6.878831e+08
# 86   {C9B8B5CF-6699-485A-97D2-74FB9B2D6FFE}  49-3-02  5.275320e+08
# 125  {FA3740D2-624B-4464-B6CD-16F6E219ADEA}  49-3-02  6.135493e+08
# 164  {908F092A-BCFF-4EA5-99D7-B9248A2EA56A}  49-3-03  1.644442e+07
#
#         ShapeSTLen                       County  ...         Party  \
# 8    280069.560289  CENTRE COUNTY, PENNSYLVANIA  ...    DEMOCRATIC
# 47   131265.443714  CENTRE COUNTY, PENNSYLVANIA  ...    DEMOCRATIC
# 86   111072.612891  CENTRE COUNTY, PENNSYLVANIA  ...    DEMOCRATIC
# 125  131038.017743  CENTRE COUNTY, PENNSYLVANIA  ...    DEMOCRATIC
# 164   19920.287608  CENTRE COUNTY, PENNSYLVANIA  ...    DEMOCRATIC
#
#                    Contest Descr                    VoteFor  \
# 8    PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 47   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 86   PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 125  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
# 164  PRESIDENTIAL ELECTORS   NaN  VOTE FOR NOT MORE THAN  1
#
#                        Candidate    Posn  Count  PctCnt Total PctTot
# 8    HILLARY CLINTON,  PRESIDENT  3318.0   45.0   21.95   NaN    NaN
# 47   HILLARY CLINTON,  PRESIDENT  5022.0  184.0   23.62   NaN    NaN
# 86   HILLARY CLINTON,  PRESIDENT  4853.0  117.0   24.17   NaN    NaN
# 125  HILLARY CLINTON,  PRESIDENT  5107.0  128.0   25.25   NaN    NaN
# 164  HILLARY CLINTON,  PRESIDENT  1128.0   83.0   25.23   NaN    NaN
#
# [5 rows x 25 columns]

# %%
# Scatter Plot for Clinton
plt.scatter(df_clinton['X'],df_clinton['Y'], s=df_clinton['PctCnt']**1.15, color = '#0077b1')
plt.suptitle('Pennsylvania Precinct Vote Percent Count for Clinton by Precinct Longitude and Latitude', fontsize=20)
plt.xlabel('longitude', fontsize=16)
plt.ylabel('latitude', fontsize=16)
plt.show()

# %% [markdown]
# ## Graphic Presentation
#
# Make sure to label all the axis, add legends and units (where appropriate).
#
#
# ## Code Quality
#
# While code performance and optimization won't count, all the code should be highly readable, and reusable. Where possible, create functions, build helper functions where needed, and make sure the code is self-explanatory.
