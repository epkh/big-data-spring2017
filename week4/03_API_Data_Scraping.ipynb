# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key_LOCAL import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='beyonce' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 17:49:42 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 13], 'text': 'keepitlocked'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tunein.com/radio/WTBOY-10…',
#      'expanded_url': 'http://tunein.com/radio/WTBOY-1075-HBG-s208454/',
#      'indices': [75, 98],
#      'url': 'https://t.co/NSrgOrMyKh'}],
#    'user_mentions': [{'id': 31239408,
#      'id_str': '31239408',
#      'indices': [19, 27],
#      'name': 'BEYONCÉ',
#      'screen_name': 'Beyonce'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836996882475921408,
#   'id_str': '836996882475921408',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sam-song.info" rel="nofollow">SAM Broadcaster Song Info</a>',
#   'text': '#keepitlocked N/P: @beyonce feat. Pharrell Williams - Blow (Remix) (Clean) https://t.co/NSrgOrMyKh',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 12:50:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I Rock Clubs, Mixtapes Parties and also a Mix Show Dj on WTBOY 107.5  HBG INTERNET RADIO EVERYDAY, SEND ME A DROP AND YOUR TRACK!! \n(CLEAN) Stop the Violence!!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wtboy1075.com',
#        'expanded_url': 'http://www.wtboy1075.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZCOSvmT7pg'}]}},
#    'favourites_count': 36,
#    'follow_request_sent': None,
#    'followers_count': 763,
#    'following': None,
#    'friends_count': 437,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 867943633,
#    'id_str': '867943633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 31,
#    'location': 'Harrisburg Pa.',
#    'name': 'WTBOY 107.5 HBG',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867943633/1421773367',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '1DJTBOYGOLD',
#    'statuses_count': 199675,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZCOSvmT7pg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 15:58:22 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 13], 'text': 'keepitlocked'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tunein.com/radio/WTBOY-10…',
#      'expanded_url': 'http://tunein.com/radio/WTBOY-1075-HBG-s208454/',
#      'indices': [53, 76],
#      'url': 'https://t.co/NSrgOrMyKh'}],
#    'user_mentions': [{'id': 31239408,
#      'id_str': '31239408',
#      'indices': [19, 27],
#      'name': 'BEYONCÉ',
#      'screen_name': 'Beyonce'},
#     {'id': 27195114,
#      'id_str': '27195114',
#      'indices': [31, 37],
#      'name': 'Drizzy',
#      'screen_name': 'Drake'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836968864529408000,
#   'id_str': '836968864529408000',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sam-song.info" rel="nofollow">SAM Broadcaster Song Info</a>',
#   'text': '#keepitlocked N/P: @beyonce ft @Drake - Mine (Clean) https://t.co/NSrgOrMyKh',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 12:50:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I Rock Clubs, Mixtapes Parties and also a Mix Show Dj on WTBOY 107.5  HBG INTERNET RADIO EVERYDAY, SEND ME A DROP AND YOUR TRACK!! \n(CLEAN) Stop the Violence!!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wtboy1075.com',
#        'expanded_url': 'http://www.wtboy1075.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZCOSvmT7pg'}]}},
#    'favourites_count': 36,
#    'follow_request_sent': None,
#    'followers_count': 763,
#    'following': None,
#    'friends_count': 437,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 867943633,
#    'id_str': '867943633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 31,
#    'location': 'Harrisburg Pa.',
#    'name': 'WTBOY 107.5 HBG',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867943633/1421773367',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '1DJTBOYGOLD',
#    'statuses_count': 199675,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZCOSvmT7pg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 14:18:57 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'local21news.com/news/entertain…',
#      'expanded_url': 'http://local21news.com/news/entertainment/lady-gaga-to-headline-coachella-in-place-of-beyonce',
#      'indices': [69, 92],
#      'url': 'https://t.co/JMvIPhfWmG'}],
#    'user_mentions': [{'id': 9651842,
#      'id_str': '9651842',
#      'indices': [3, 13],
#      'name': 'CBS 21 News',
#      'screen_name': 'CBS21NEWS'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836943847137689600,
#   'id_str': '836943847137689600',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 01 14:15:02 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'local21news.com/news/entertain…',
#       'expanded_url': 'http://local21news.com/news/entertainment/lady-gaga-to-headline-coachella-in-place-of-beyonce',
#       'indices': [54, 77],
#       'url': 'https://t.co/JMvIPhfWmG'}],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 836942859517341697,
#    'id_str': '836942859517341697',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Lady Gaga to headline Coachella in place of Beyonce \n\nhttps://t.co/JMvIPhfWmG',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Oct 24 12:18:54 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Your station for news, sports and weather in Central Pennsylvania.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'local21news.com',
#         'expanded_url': 'http://www.local21news.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/GeDcKVs5WO'}]}},
#     'favourites_count': 809,
#     'follow_request_sent': None,
#     'followers_count': 49355,
#     'following': None,
#     'friends_count': 873,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 9651842,
#     'id_str': '9651842',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 670,
#     'location': 'Harrisburg, Pennsylvania, USA',
#     'name': 'CBS 21 News',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#     'profile_link_color': 'E60003',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'E8E8E8',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'CBS21NEWS',
#     'statuses_count': 147964,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/GeDcKVs5WO',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @CBS21NEWS: Lady Gaga to headline Coachella in place of Beyonce \n\nhttps://t.co/JMvIPhfWmG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 24 15:42:51 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'spittari????',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wwss.com',
#        'expanded_url': 'http://www.wwss.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/5fvaU7vcKx'}]}},
#    'favourites_count': 12129,
#    'follow_request_sent': None,
#    'followers_count': 778,
#    'following': None,
#    'friends_count': 523,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2506454993,
#    'id_str': '2506454993',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'fi',
#    'listed_count': 232,
#    'location': 'wpekkaw',
#    'name': 'pekkaww',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2506454993/1412660350',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/519369829456048128/ijGUTElW_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/519369829456048128/ijGUTElW_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'PVirkka',
#    'statuses_count': 64403,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/5fvaU7vcKx',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 14:15:02 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'local21news.com/news/entertain…',
#      'expanded_url': 'http://local21news.com/news/entertainment/lady-gaga-to-headline-coachella-in-place-of-beyonce',
#      'indices': [54, 77],
#      'url': 'https://t.co/JMvIPhfWmG'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 836942859517341697,
#   'id_str': '836942859517341697',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'Lady Gaga to headline Coachella in place of Beyonce \n\nhttps://t.co/JMvIPhfWmG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Oct 24 12:18:54 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Your station for news, sports and weather in Central Pennsylvania.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'local21news.com',
#        'expanded_url': 'http://www.local21news.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/GeDcKVs5WO'}]}},
#    'favourites_count': 809,
#    'follow_request_sent': None,
#    'followers_count': 49355,
#    'following': None,
#    'friends_count': 873,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 9651842,
#    'id_str': '9651842',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 670,
#    'location': 'Harrisburg, Pennsylvania, USA',
#    'name': 'CBS 21 News',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#    'profile_link_color': 'E60003',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'E8E8E8',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CBS21NEWS',
#    'statuses_count': 147964,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/GeDcKVs5WO',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 12:01:52 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 11], 'text': 'Harrisburg'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ow.ly/HjKH509T1lR',
#      'expanded_url': 'http://ow.ly/HjKH509T1lR',
#      'indices': [65, 88],
#      'url': 'https://t.co/w0bD3DKBqG'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836909349037608960,
#   'id_str': '836909349037608960',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': '#Harrisburg: Lady Gaga to headline Coachella in place of Beyonce https://t.co/w0bD3DKBqG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Nov 24 16:11:59 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#Harrisburg #News, #Gossip, #Politics, #Photos, #Lancaster, #York, #Carlisle, #Pennsylvania, #Watchdogs',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'harrisburgers.com',
#        'expanded_url': 'http://www.harrisburgers.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/hrLla8TqQC'}]}},
#    'favourites_count': 151,
#    'follow_request_sent': None,
#    'followers_count': 4356,
#    'following': None,
#    'friends_count': 4197,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 92304777,
#    'id_str': '92304777',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 187,
#    'location': 'Harrisburg, PA',
#    'name': 'Harrisburgers',
#    'notifications': None,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/755083254/e49de50a24ed177917320de17f146e4a.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/755083254/e49de50a24ed177917320de17f146e4a.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/92304777/1451145776',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/680781080371265536/_BqnFzqu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/680781080371265536/_BqnFzqu_normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'harrisburgers',
#    'statuses_count': 188267,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/hrLla8TqQC',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 10:49:17 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'wp.me/p5hgQ6-21H5',
#      'expanded_url': 'http://wp.me/p5hgQ6-21H5',
#      'indices': [52, 75],
#      'url': 'https://t.co/rflB1BXV1G'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836891084202606593,
#   'id_str': '836891084202606593',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'text': 'Lady Gaga to headline Coachella in place of Beyonce https://t.co/rflB1BXV1G',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jun 17 12:36:05 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Central Pennsylvania's leader in local news, sports and information. Social media policy: https://t.co/XJQMn2Ij0R",
#    'entities': {'description': {'urls': [{'display_url': 'abc27.com/social-media-p…',
#        'expanded_url': 'http://abc27.com/social-media-policy/',
#        'indices': [90, 113],
#        'url': 'https://t.co/XJQMn2Ij0R'}]},
#     'url': {'urls': [{'display_url': 'abc27.com',
#        'expanded_url': 'http://www.abc27.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/INzj9IQB4I'}]}},
#    'favourites_count': 945,
#    'follow_request_sent': None,
#    'followers_count': 83450,
#    'following': None,
#    'friends_count': 850,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 15145034,
#    'id_str': '15145034',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 726,
#    'location': 'Harrisburg, PA',
#    'name': 'abc27 WHTM',
#    'notifications': None,
#    'profile_background_color': '050505',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/880914624/445a265e97670072b6d5500a5c7f15d0.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/880914624/445a265e97670072b6d5500a5c7f15d0.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15145034/1486059038',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/802173436655181825/ef98EOnl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/802173436655181825/ef98EOnl_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'abc27News',
#    'statuses_count': 120263,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/INzj9IQB4I',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 06:12:57 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 13], 'text': 'keepitlocked'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tunein.com/radio/WTBOY-10…',
#      'expanded_url': 'http://tunein.com/radio/WTBOY-1075-HBG-s208454/',
#      'indices': [89, 112],
#      'url': 'https://t.co/NSrgOrMyKh'}],
#    'user_mentions': [{'id': 31239408,
#      'id_str': '31239408',
#      'indices': [19, 27],
#      'name': 'BEYONCÉ',
#      'screen_name': 'Beyonce'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836821541212024833,
#   'id_str': '836821541212024833',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sam-song.info" rel="nofollow">SAM Broadcaster Song Info</a>',
#   'text': '#keepitlocked N/P: @beyonce feat. Jay Z &amp; Kanye West - Drunk In Love (Remix) (Clean) https://t.co/NSrgOrMyKh',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 12:50:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I Rock Clubs, Mixtapes Parties and also a Mix Show Dj on WTBOY 107.5  HBG INTERNET RADIO EVERYDAY, SEND ME A DROP AND YOUR TRACK!! \n(CLEAN) Stop the Violence!!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wtboy1075.com',
#        'expanded_url': 'http://www.wtboy1075.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZCOSvmT7pg'}]}},
#    'favourites_count': 36,
#    'follow_request_sent': None,
#    'followers_count': 763,
#    'following': None,
#    'friends_count': 437,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 867943633,
#    'id_str': '867943633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 31,
#    'location': 'Harrisburg Pa.',
#    'name': 'WTBOY 107.5 HBG',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867943633/1421773367',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '1DJTBOYGOLD',
#    'statuses_count': 199675,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZCOSvmT7pg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 01 00:10:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'trib.al/zNsCX0F',
#      'expanded_url': 'http://trib.al/zNsCX0F',
#      'indices': [52, 75],
#      'url': 'https://t.co/U22IQYJ6YO'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836730244363079680,
#   'id_str': '836730244363079680',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'Lady Gaga Will Replace Beyonce At Coachella: Report https://t.co/U22IQYJ6YO',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 20 16:52:32 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "99.3 KISS FM is Central PA's Hit Music Station!",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': '993kissfm.com',
#        'expanded_url': 'http://www.993kissfm.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/NX7XZSFu3c'}]}},
#    'favourites_count': 522,
#    'follow_request_sent': None,
#    'followers_count': 9020,
#    'following': None,
#    'friends_count': 471,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 33578280,
#    'id_str': '33578280',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 128,
#    'location': 'Harrisburg, PA',
#    'name': '99.3 KISS FM',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33578280/1444054191',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/615505507831263232/bgDlrZZ8_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/615505507831263232/bgDlrZZ8_normal.png',
#    'profile_link_color': 'DB11CE',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'kissfm993',
#    'statuses_count': 72752,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/NX7XZSFu3c',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Feb 28 20:25:19 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 13], 'text': 'keepitlocked'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tunein.com/radio/WTBOY-10…',
#      'expanded_url': 'http://tunein.com/radio/WTBOY-1075-HBG-s208454/',
#      'indices': [45, 68],
#      'url': 'https://t.co/NSrgOrMyKh'}],
#    'user_mentions': [{'id': 31239408,
#      'id_str': '31239408',
#      'indices': [19, 27],
#      'name': 'BEYONCÉ',
#      'screen_name': 'Beyonce'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836673660362555393,
#   'id_str': '836673660362555393',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sam-song.info" rel="nofollow">SAM Broadcaster Song Info</a>',
#   'text': '#keepitlocked N/P: @beyonce - Rocket (Clean) https://t.co/NSrgOrMyKh',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 12:50:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I Rock Clubs, Mixtapes Parties and also a Mix Show Dj on WTBOY 107.5  HBG INTERNET RADIO EVERYDAY, SEND ME A DROP AND YOUR TRACK!! \n(CLEAN) Stop the Violence!!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wtboy1075.com',
#        'expanded_url': 'http://www.wtboy1075.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZCOSvmT7pg'}]}},
#    'favourites_count': 36,
#    'follow_request_sent': None,
#    'followers_count': 763,
#    'following': None,
#    'friends_count': 437,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 867943633,
#    'id_str': '867943633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 31,
#    'location': 'Harrisburg Pa.',
#    'name': 'WTBOY 107.5 HBG',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867943633/1421773367',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '1DJTBOYGOLD',
#    'statuses_count': 199675,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZCOSvmT7pg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Feb 28 20:05:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1612320433,
#      'id_str': '1612320433',
#      'indices': [0, 9],
#      'name': 'YONCÉ',
#      'screen_name': 'GleekAli'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836668545496862722,
#   'id_str': '836668545496862722',
#   'in_reply_to_screen_name': 'GleekAli',
#   'in_reply_to_status_id': 836668271906676736,
#   'in_reply_to_status_id_str': '836668271906676736',
#   'in_reply_to_user_id': 1612320433,
#   'in_reply_to_user_id_str': '1612320433',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "@GleekAli Whoever Kehlani is-that statement isn't true! Beyoncé SLAYS!",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Sep 17 02:16:46 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I'm a fanboy of Glee, #Supergirl & #Riverdale! I ship #Finchel, #Brittana & #Sanvers! My GF-@DemiLeaRivera",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 39320,
#    'follow_request_sent': None,
#    'followers_count': 2027,
#    'following': None,
#    'friends_count': 2832,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1873757142,
#    'id_str': '1873757142',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 26,
#    'location': 'Grantville,PA',
#    'name': 'Adam Herr',
#    'notifications': None,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000089575258/22331b440cc1ec1a73567aacf6f09108.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000089575258/22331b440cc1ec1a73567aacf6f09108.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1873757142/1469196265',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/810482598048739328/Pfnyrtih_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810482598048739328/Pfnyrtih_normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thepeppygleek',
#    'statuses_count': 66386,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Feb 28 07:25:09 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3196318851,
#      'id_str': '3196318851',
#      'indices': [3, 12],
#      'name': 'X&',
#      'screen_name': 'akikozue'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836477322987466753,
#   'id_str': '836477322987466753',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'fr',
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Feb 27 22:02:45 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 836335791546765316,
#    'id_str': '836335791546765316',
#    'in_reply_to_screen_name': 'akikozue',
#    'in_reply_to_status_id': 836329803074654209,
#    'in_reply_to_status_id_str': '836329803074654209',
#    'in_reply_to_user_id': 3196318851,
#    'in_reply_to_user_id_str': '3196318851',
#    'is_quote_status': False,
#    'lang': 'fr',
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "🌺 queen de ouf . t'es la beyonce de ma tl, ton maquillage on fleek là...épouse moi ines .",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 22 23:53:46 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'tro la honte',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 301,
#     'follow_request_sent': None,
#     'followers_count': 358,
#     'following': None,
#     'friends_count': 54,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 3196318851,
#     'id_str': '3196318851',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'fr',
#     'listed_count': 17,
#     'location': 'qntn',
#     'name': 'X&',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/673540131559710720/UL3cIiIE.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/673540131559710720/UL3cIiIE.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3196318851/1488284876',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/836604529139404800/q8MZyf0S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836604529139404800/q8MZyf0S_normal.jpg',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'akikozue',
#     'statuses_count': 25862,
#     'time_zone': 'Belgrade',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @akikozue: 🌺 queen de ouf . t'es la beyonce de ma tl, ton maquillage on fleek là...épouse moi ines .",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Apr 24 15:03:40 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '[+86, -6] Black people provide all the entertainment only for the white people to take home all the awards',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1547,
#    'follow_request_sent': None,
#    'followers_count': 404,
#    'following': None,
#    'friends_count': 59,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 3201318117,
#    'id_str': '3201318117',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'fr',
#    'listed_count': 8,
#    'location': '#BLM',
#    'name': 'nes',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3201318117/1488145040',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835578132145049601/PXfz9ZDo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835578132145049601/PXfz9ZDo_normal.jpg',
#    'profile_link_color': '111111',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'xshutoku',
#    'statuses_count': 10314,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 27 22:02:45 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 836335791546765316,
#   'id_str': '836335791546765316',
#   'in_reply_to_screen_name': 'akikozue',
#   'in_reply_to_status_id': 836329803074654209,
#   'in_reply_to_status_id_str': '836329803074654209',
#   'in_reply_to_user_id': 3196318851,
#   'in_reply_to_user_id_str': '3196318851',
#   'is_quote_status': False,
#   'lang': 'fr',
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "🌺 queen de ouf . t'es la beyonce de ma tl, ton maquillage on fleek là...épouse moi ines .",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Apr 22 23:53:46 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'tro la honte',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 301,
#    'follow_request_sent': None,
#    'followers_count': 358,
#    'following': None,
#    'friends_count': 54,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 3196318851,
#    'id_str': '3196318851',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'fr',
#    'listed_count': 17,
#    'location': 'qntn',
#    'name': 'X&',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/673540131559710720/UL3cIiIE.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/673540131559710720/UL3cIiIE.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3196318851/1488284876',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/836604529139404800/q8MZyf0S_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836604529139404800/q8MZyf0S_normal.jpg',
#    'profile_link_color': '7FDBB6',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'akikozue',
#    'statuses_count': 25862,
#    'time_zone': 'Belgrade',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 27 15:08:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/mSfWVVvhdi',
#      'expanded_url': 'https://twitter.com/SamarRaining/status/836229445161746432/video/1',
#      'id': 836228313811148800,
#      'id_str': '836228313811148800',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 836229445161746432,
#      'source_status_id_str': '836229445161746432',
#      'source_user_id': 722884291,
#      'source_user_id_str': '722884291',
#      'type': 'photo',
#      'url': 'https://t.co/mSfWVVvhdi'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 722884291,
#      'id_str': '722884291',
#      'indices': [3, 16],
#      'name': 'Samar Mattar',
#      'screen_name': 'SamarRaining'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#       'source_user': {'contributors_enabled': False,
#        'created_at': 'Sat Jul 28 21:52:54 +0000 2012',
#        'default_profile': False,
#        'default_profile_image': False,
#        'description': 'MUFC❤️',
#        'entities': {'description': {'urls': []}},
#        'favourites_count': 528,
#        'follow_request_sent': None,
#        'followers_count': 340,
#        'following': None,
#        'friends_count': 201,
#        'geo_enabled': True,
#        'has_extended_profile': True,
#        'id': 722884291,
#        'id_str': '722884291',
#        'is_translation_enabled': False,
#        'is_translator': False,
#        'lang': 'en',
#        'listed_count': 2,
#        'location': 'Violet Hill',
#        'name': 'Samar Mattar',
#        'notifications': None,
#        'profile_background_color': '417ADB',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#        'profile_background_tile': True,
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/722884291/1486693980',
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#        'profile_link_color': 'B40B43',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'protected': False,
#        'screen_name': 'SamarRaining',
#        'statuses_count': 11434,
#        'time_zone': 'Kuwait',
#        'translator_type': 'none',
#        'url': None,
#        'utc_offset': 10800,
#        'verified': False}},
#      'display_url': 'pic.twitter.com/mSfWVVvhdi',
#      'expanded_url': 'https://twitter.com/SamarRaining/status/836229445161746432/video/1',
#      'id': 836228313811148800,
#      'id_str': '836228313811148800',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 836229445161746432,
#      'source_status_id_str': '836229445161746432',
#      'source_user_id': 722884291,
#      'source_user_id_str': '722884291',
#      'type': 'video',
#      'url': 'https://t.co/mSfWVVvhdi',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 140027,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/640x360/HrZdi7z_ipZUgjsA.mp4'},
#        {'content_type': 'application/dash+xml',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.mpd'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.m3u8'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/320x180/N20Qqpd13AJmgdXn.mp4'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836231458754871296,
#   'id_str': '836231458754871296',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Feb 27 15:00:10 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/mSfWVVvhdi',
# ...
#       'id': 836228313811148800,
#       'id_str': '836228313811148800',
#       'indices': [27, 50],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/mSfWVVvhdi',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 140027,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/640x360/HrZdi7z_ipZUgjsA.mp4'},
#         {'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.mpd'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.m3u8'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/320x180/N20Qqpd13AJmgdXn.mp4'}]}}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 836229445161746432,
#    'id_str': '836229445161746432',
#    'in_reply_to_screen_name': 'SamarRaining',
#    'in_reply_to_status_id': 835865325472219138,
#    'in_reply_to_status_id_str': '835865325472219138',
#    'in_reply_to_user_id': 722884291,
#    'in_reply_to_user_id_str': '722884291',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '5. Beyoncé - Crazy In Love https://t.co/mSfWVVvhdi',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jul 28 21:52:54 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'MUFC❤️',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 528,
#     'follow_request_sent': None,
#     'followers_count': 340,
#     'following': None,
#     'friends_count': 201,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 722884291,
#     'id_str': '722884291',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'Violet Hill',
#     'name': 'Samar Mattar',
#     'notifications': None,
#     'profile_background_color': '417ADB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/722884291/1486693980',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#     'profile_link_color': 'B40B43',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SamarRaining',
#     'statuses_count': 11434,
#     'time_zone': 'Kuwait',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 10800,
#     'verified': False}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#   'text': 'RT @SamarRaining: 5. Beyoncé - Crazy In Love https://t.co/mSfWVVvhdi',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jan 31 09:09:05 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Life is but a dream \n\n👑',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 188,
#    'follow_request_sent': None,
#    'followers_count': 31,
#    'following': None,
#    'friends_count': 68,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 826356619139223554,
#    'id_str': '826356619139223554',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Port Elizabeth, South Africa',
#    'name': 'Tamie',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/826356619139223554/1485875655',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/826448523189166080/x-LlkGYM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826448523189166080/x-LlkGYM_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'miss_tamie',
#    'statuses_count': 128,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 27 15:00:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/mSfWVVvhdi',
#      'expanded_url': 'https://twitter.com/SamarRaining/status/836229445161746432/video/1',
#      'id': 836228313811148800,
#      'id_str': '836228313811148800',
#      'indices': [27, 50],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/mSfWVVvhdi'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#      'display_url': 'pic.twitter.com/mSfWVVvhdi',
#      'expanded_url': 'https://twitter.com/SamarRaining/status/836229445161746432/video/1',
#      'id': 836228313811148800,
#      'id_str': '836228313811148800',
#      'indices': [27, 50],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/836228313811148800/pu/img/MC5OpjScWE15Yhb0.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'video',
#      'url': 'https://t.co/mSfWVVvhdi',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 140027,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/640x360/HrZdi7z_ipZUgjsA.mp4'},
#        {'content_type': 'application/dash+xml',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.mpd'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/pl/1OuW3rvzkhs7IKUs.m3u8'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/836228313811148800/pu/vid/320x180/N20Qqpd13AJmgdXn.mp4'}]}}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 836229445161746432,
#   'id_str': '836229445161746432',
#   'in_reply_to_screen_name': 'SamarRaining',
#   'in_reply_to_status_id': 835865325472219138,
#   'in_reply_to_status_id_str': '835865325472219138',
#   'in_reply_to_user_id': 722884291,
#   'in_reply_to_user_id_str': '722884291',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '5. Beyoncé - Crazy In Love https://t.co/mSfWVVvhdi',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 28 21:52:54 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'MUFC❤️',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 528,
#    'follow_request_sent': None,
#    'followers_count': 340,
#    'following': None,
#    'friends_count': 201,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 722884291,
#    'id_str': '722884291',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Violet Hill',
#    'name': 'Samar Mattar',
#    'notifications': None,
#    'profile_background_color': '417ADB',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/722884291/1486693980',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835963427973574657/YD6B_gvr_normal.jpg',
#    'profile_link_color': 'B40B43',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SamarRaining',
#    'statuses_count': 11434,
#    'time_zone': 'Kuwait',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Feb 27 08:22:43 +0000 2017',
#   'entities': {'hashtags': [{'indices': [124, 131], 'text': 'Oscars'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 4884021464,
#      'id_str': '4884021464',
#      'indices': [3, 11],
#      'name': 'Henry Boima Johnson',
#      'screen_name': 'hank259'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 836129421396488193,
#   'id_str': '836129421396488193',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 37,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Feb 27 04:53:21 +0000 2017',
#    'entities': {'hashtags': [{'indices': [111, 118], 'text': 'Oscars'},
#      {'indices': [119, 139], 'text': 'BGNOscarsWatchParty'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 60,
#    'favorited': False,
#    'geo': None,
#    'id': 836076734432833537,
#    'id_str': '836076734432833537',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 37,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '2017. When Adele wins an award Beyonce earned/deserved. And when Casey wins an award Denzel earned/deserved. \n\n#Oscars #BGNOscarsWatchParty',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 09 17:19:32 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Jesus follower, people lover, quarter life crisis survivor, food eater, sports cheerer, husband and father, son and brother, trying to live and love like Jesus.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 79951,
#     'follow_request_sent': None,
#     'followers_count': 850,
#     'following': None,
#     'friends_count': 814,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 4884021464,
#     'id_str': '4884021464',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 29,
#     'location': 'Harrisburg, PA',
#     'name': 'Henry Boima Johnson',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4884021464/1455088779',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/819054922960355328/aamKrj2S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/819054922960355328/aamKrj2S_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'hank259',
#     'statuses_count': 20123,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @hank259: 2017. When Adele wins an award Beyonce earned/deserved. And when Casey wins an award Denzel earned/deserved. \n\n#Oscars #BGNOsc…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 29 14:13:38 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Purpose',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 44940,
#    'follow_request_sent': None,
#    'followers_count': 498,
#    'following': None,
#    'friends_count': 1049,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1044983342,
#    'id_str': '1044983342',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 8,
#    'location': 'Hertfordshire',
#    'name': 'Funke Oduwole',
#    'notifications': None,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1044983342/1479259247',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/823481798982242305/KwMCrIyy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/823481798982242305/KwMCrIyy_normal.jpg',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'OduwoleF',
#    'statuses_count': 8457,
#    'time_zone': 'Europe/London',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir ## allows us to get files from our computers
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 836943847137689600  836943847137689600  None  None
# 836942859517341697  836942859517341697  None  None
# 836909349037608960  836909349037608960  None  None
# 836891084202606593  836891084202606593  None  None
# 836821541212024833  836821541212024833  None  None
# 836730244363079680  836730244363079680  None  None
# 836673660362555393  836673660362555393  None  None
# 836668545496862722  836668545496862722  None  None
# 836477322987466753  836477322987466753  None  None
# 836335791546765316  836335791546765316  None  None
# 836231458754871296  836231458754871296  None  None
# 836229445161746432  836229445161746432  None  None
# 836129421396488193  836129421396488193  None  None
# 836128021383872515  836128021383872515  None  None
# 836091669497798656  836091669497798656  None  None
#
#                                                               content  \
# 836943847137689600  RT @CBS21NEWS: Lady Gaga to headline Coachella...
# 836942859517341697  Lady Gaga to headline Coachella in place of Be...
# 836909349037608960  #Harrisburg: Lady Gaga to headline Coachella i...
# 836891084202606593  Lady Gaga to headline Coachella in place of Be...
# 836821541212024833  #keepitlocked N/P: @beyonce feat. Jay Z &amp; ...
# 836730244363079680  Lady Gaga Will Replace Beyonce At Coachella: R...
# 836673660362555393  #keepitlocked N/P: @beyonce - Rocket (Clean) h...
# 836668545496862722  @GleekAli Whoever Kehlani is-that statement is...
# 836477322987466753  RT @akikozue: 🌺 queen de ouf . t'es la beyonce...
# 836335791546765316  🌺 queen de ouf . t'es la beyonce de ma tl, ton...
# 836231458754871296  RT @SamarRaining: 5. Beyoncé - Crazy In Love h...
# 836229445161746432  5. Beyoncé - Crazy In Love https://t.co/mSfWVV...
# 836129421396488193  RT @hank259: 2017. When Adele wins an award Be...
# 836128021383872515  RT @hank259: 2017. When Adele wins an award Be...
# 836091669497798656  RT @hank259: 2017. When Adele wins an award Be...
#
#                                          location                user  \
# 836943847137689600                        wpekkaw          2506454993
# 836942859517341697  Harrisburg, Pennsylvania, USA             9651842
# 836909349037608960                 Harrisburg, PA            92304777
# 836891084202606593                 Harrisburg, PA            15145034
# 836821541212024833                 Harrisburg Pa.           867943633
# 836730244363079680                 Harrisburg, PA            33578280
# 836673660362555393                 Harrisburg Pa.           867943633
# 836668545496862722                  Grantville,PA          1873757142
# 836477322987466753                           #BLM          3201318117
# 836335791546765316                           qntn          3196318851
# 836231458754871296   Port Elizabeth, South Africa  826356619139223554
# 836229445161746432                    Violet Hill           722884291
# 836129421396488193                  Hertfordshire          1044983342
# 836128021383872515                                          529271460
# 836091669497798656              San Francisco, CA          1461252662
#
#                                                            raw_source  \
# 836943847137689600  {'created_at': 'Wed Mar 01 14:18:57 +0000 2017...
# 836942859517341697  {'created_at': 'Wed Mar 01 14:15:02 +0000 2017...
# 836909349037608960  {'created_at': 'Wed Mar 01 12:01:52 +0000 2017...
# 836891084202606593  {'created_at': 'Wed Mar 01 10:49:17 +0000 2017...
# 836821541212024833  {'created_at': 'Wed Mar 01 06:12:57 +0000 2017...
# 836730244363079680  {'created_at': 'Wed Mar 01 00:10:10 +0000 2017...
# 836673660362555393  {'created_at': 'Tue Feb 28 20:25:19 +0000 2017...
# 836668545496862722  {'created_at': 'Tue Feb 28 20:05:00 +0000 2017...
# 836477322987466753  {'created_at': 'Tue Feb 28 07:25:09 +0000 2017...
# 836335791546765316  {'created_at': 'Mon Feb 27 22:02:45 +0000 2017...
# 836231458754871296  {'created_at': 'Mon Feb 27 15:08:10 +0000 2017...
# 836229445161746432  {'created_at': 'Mon Feb 27 15:00:10 +0000 2017...
# 836129421396488193  {'created_at': 'Mon Feb 27 08:22:43 +0000 2017...
# 836128021383872515  {'created_at': 'Mon Feb 27 08:17:09 +0000 2017...
# 836091669497798656  {'created_at': 'Mon Feb 27 05:52:42 +0000 2017...
#
#                    data_point                            time
# 836943847137689600       none  Wed Mar 01 14:18:57 +0000 2017
# 836942859517341697       none  Wed Mar 01 14:15:02 +0000 2017
# 836909349037608960       none  Wed Mar 01 12:01:52 +0000 2017
# 836891084202606593       none  Wed Mar 01 10:49:17 +0000 2017
# 836821541212024833       none  Wed Mar 01 06:12:57 +0000 2017
# 836730244363079680       none  Wed Mar 01 00:10:10 +0000 2017
# 836673660362555393       none  Tue Feb 28 20:25:19 +0000 2017
# 836668545496862722       none  Tue Feb 28 20:05:00 +0000 2017
# 836477322987466753       none  Tue Feb 28 07:25:09 +0000 2017
# 836335791546765316       none  Mon Feb 27 22:02:45 +0000 2017
# 836231458754871296       none  Mon Feb 27 15:08:10 +0000 2017
# 836229445161746432       none  Mon Feb 27 15:00:10 +0000 2017
# 836129421396488193       none  Mon Feb 27 08:22:43 +0000 2017
# 836128021383872515       none  Mon Feb 27 08:17:09 +0000 2017
# 836091669497798656       none  Mon Feb 27 05:52:42 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['wpekkaw', 'Harrisburg, Pennsylvania, USA', 'Harrisburg, PA',
#        'Harrisburg Pa.', 'Grantville,PA', '#BLM', 'qntn',
#        'Port Elizabeth, South Africa', 'Violet Hill', 'Hertfordshire', '',
#        'San Francisco, CA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                                Count
# Location
#                                    1
# #BLM                               1
# Grantville,PA                      1
# Harrisburg Pa.                     2
# Harrisburg, PA                     3
# Harrisburg, Pennsylvania, USA      1
# Hertfordshire                      1
# Port Elizabeth, South Africa       1
# San Francisco, CA                  1
# Violet Hill                        1
# qntn                               1
# wpekkaw                            1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/phoebe/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/phoebe/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/phoebe/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/phoebe/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['Harrisburg, Pennsylvania, USA','Harrisburg, PA','Harrisburg Pa.']

df_tweets['location'].replace(variations_of_york, 'Harrisburg, PA')
# Out:
# 836943847137689600                         wpekkaw
# 836942859517341697                  Harrisburg, PA
# 836909349037608960                  Harrisburg, PA
# 836891084202606593                  Harrisburg, PA
# 836821541212024833                  Harrisburg, PA
# 836730244363079680                  Harrisburg, PA
# 836673660362555393                  Harrisburg, PA
# 836668545496862722                   Grantville,PA
# 836477322987466753                            #BLM
# 836335791546765316                            qntn
# 836231458754871296    Port Elizabeth, South Africa
# 836229445161746432                     Violet Hill
# 836129421396488193                   Hertfordshire
# 836128021383872515
# 836091669497798656               San Francisco, CA
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
